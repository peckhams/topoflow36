# %% [markdown]
# # Running TopoFlow for the Tana River, Kenya

# %% [markdown]
# #### Table of Contents

# %% [markdown]
# 1.  <a href="#Import">Import Required Packages</a> <br>
# 2.  <a href="#Intro">Introduction</a> <br>
# 3.  <a href="#Test1">CHIRPS 6-hr Rainfall, with No Infiltration</a> <br>
# 4.  <a href="#show_grid">Show One Grid from the RTS File</a> <br>
# 5.  <a href="#plot_data">Plot a Time Series for Outlet Values</a> <br>
# 6.  <a href="#Test2">CHIRPS 6-hr Rainfall, with Richards 1D Infiltration</a> <br>

# %% [markdown]
# ## Import Required Packages <a id="Import"></a>

# %%
from topoflow import main
from topoflow.framework import emeli
examples_dir = emeli.paths['examples']
import os, os.path
from topoflow.utils import visualize as tfvis
from topoflow.utils import rts_files

# from topoflow.utils import rtg_files

home_dir   = os.path.expanduser("~")
cfg_prefix = 'Test1'
cfg_dir    = home_dir + '/TF_Tests/Tana_120sec/Test1_cfg/'
output_dir = home_dir + '/TF_Tests/Tana_120sec/'

print('Examples directory  =', examples_dir)
print('Your Home directory =', home_dir)
print('CFG directory       =', cfg_dir)
print('Output directory    =', output_dir)
# Out:
# Importing TopoFlow 3.6 package modules:
#    topoflow.utils
#    topoflow.utils.tests
#    topoflow.components
#    topoflow.components.tests
#    topoflow.framework
#    topoflow.framework.tests
#
# Examples directory  = /Users/peckhams/Dropbox/TopoFlow_3.6/topoflow/examples/
# Your Home directory = /Users/peckhams
# CFG directory       = /Users/peckhams/TF_Tests/Tana_120sec/Test1_cfg/
# Output directory    = /Users/peckhams/TF_Tests/Tana_120sec/

# %% [markdown]
# ## Introduction <a id="Intro"></a>

# %% [markdown]
# This notebook assumes that you are already familiar with the basic concepts of TopoFlow and how to run it.  The Jupyter notebook called <b>TopoFlow_Getting_Started.ipynb</b> provides that information.
#
# This notebook also assumes that you have already created all of the input files needed to run TopoFlow for the Tana River basin.  The Jupyter notebook called <b>TopoFlow_Prepare_Input_Data.ipynb</b> can be used for that purpose.

# %% [markdown]
# ## Test1:  CHIRPS Rainfall & Runoff, with No Infiltration  <a id="Test1"></a>

# %% [markdown]
# In this test, we use space-time rainfall from the CHIRPS rainfall product, as specified in the CFG file for the Meteorology component.  (Note that the timestep, dt in Test1_meteorology.cfg should be set to: 21600 seconds, or 6 hours.) For the channel flow process, we use the Kinematic Wave method.  So only 2 process components are enabled, namely:  <b>Meteorology</b> and <b>Channels - Kinematic Wave</b>.  All other processes (infiltration, evaporation, snowmelt, icemelt, diversions) have <b>comp_status</b> set to Disabled in their CFG files.  The case prefix for this scenario is <b>Test1</b>.

# %%
main.run_model(cfg_prefix=cfg_prefix, cfg_directory=cfg_dir)
# Out:
# EMELI: Reading info from provider_file:
#     /Users/peckhams/TF_Tests/Tana_120sec/Test1_cfg/Test1_providers.txt
# EMELI: Reading info from comp_repo_file:
#     /Users/peckhams/Dropbox/TopoFlow_3.6/topoflow/framework/component_repository.xml
#
# EMELI: Instantiated component: tf_meteorology
# EMELI: Instantiated component: tf_diversions_fraction_method
# EMELI: Instantiated component: tf_channels_kin_wave
# EMELI: Instantiated component: tf_snow_degree_day
# EMELI: Instantiated component: tf_satzone_attenuate
# EMELI: Instantiated component: tf_evap_priestley_taylor
# EMELI: Instantiated component: tf_infil_richards_1d
# EMELI: Instantiated component: tf_ice_gc2d
# EMELI: Instantiated component: topoflow_driver
# Driver component name = topoflow_driver
#
# Meteorology component: Initializing...
# Reading config file into component state.
# In met_base read_input_files():
#    time = 0.0
#    min(P) = 0.0 [mmph]
#    max(P) = 0.0052423921204081125 [mmph]
#
# ------------------------------------------
#  NOTE: Since PRECIP_ONLY = True, output
#        variables for met component will
#        not be computed or saved to files.
#        And evap component may not work.
# ------------------------------------------
#
# EMELI: Initialized component: tf_meteorology.
#
# Diversions component: Initializing...
# Reading config file into component state.
# Diversions component: Disabled in CFG file.
# EMELI: Initialized component: tf_diversions_fraction_method.
#
# Channels component: Initializing...
# Reading config file into component state.
# CHANNELS calling initialize_d8_vars()...
# D8 component: Initializing...
# Reading config file into component state.
# Reading grid values...
# Finished reading grid from:
#   /Users/peckhams/TF_Tests/Tana_120sec/__topo/Tana_120sec_DEM.rtg
#    min(DEM), max(DEM) = 0.0 5269.4604
#
# Filling pits in initial DEM...
# Number of nodata and NaN values = 0
# Finished initializing "closed" array.
#
# Putting boundary pixels on heap...
# Number of pixels on heap = 488
# Finished with heap insertion.
#
# n_closed = 0 of 15065
# n_closed = 5000 of 15065
# n_closed = 10000 of 15065
# n_closed = 15000 of 15065
# Total pixels   = 15065
# Raised  pixels = 0
# Drained pixels = 15067
# Run time for fill_pits() =     0.2322 [seconds]
# Finished with fill_pits().
#
# Imported netCDF4 version: 1.5.7
# D8 component: Updating...
# Updating D8 flow grid...
#    update_d8_codes(): Initializing grid...
#    --------------------------------------------
#    Data type of flow grid at start = int16
#    Number of flats         = 482
#    Number of 1-pixel pits  = 13
#    Number of nodata/NaN    = 346
#    min(codes), max(codes)  = -255, 136
#    --------------------------------------------
#    update_d8_codes(): Breaking ties...
#    update_d8_codes(): Linking flats...
#    Number of iterations = 13 (in link_flats())
# Updating flow width grid...
#     min(dw), max(dw) = 3685.809, 5230.1157 [m]
# Updating flow length grid...
#     min(ds), max(ds) = 3685.809, 5230.1157 [m]
# Updating upstream area grid...
#     min(A), max(A) = 0.0, 94284.44 [km^2]
#     Number of iterations = 175
# Saving D8 grids specified in CFG file...
# CHANNELS calling read_input_files()...
# CHANNELS calling set_computed_input_vars()...
# --------------------------------------------------
# NOTE:  save_pixels_dt read from CFG file is less
#        than the channel component timestep, dt.
#        Will write values at interval dt instead.
# --------------------------------------------------
#
# CHANNELS calling initialize_computed_vars()...
#     min(nval)       = 0.030000001192092896
#     max(nval)       = 1.0
#     min(width)      = 1.0
#     max(width)      = 120.0
#     min(angle)      = 29.999999999999996 [deg]
#     max(angle)      = 29.999999999999996 [deg]
#     min(sinuosity)  = 1.0
#     max(sinuosity)  = 1.0
#     min(init_depth) = 0.0006527226651087403
#     max(init_depth) = 2.5116665363311768
# Initializing u, f, d grids...
# Total number of slope values = 15065
# Number of zero values        = 730 (maybe edge)
# Number of negative values    = 0
# Number of NaN values         = 0
# Number of infinite values    = 0
# -------------------------------------------------
# WARNING: Zero, negative or NaN slopes found.
#          Replacing them with smallest slope.
#          Consider using "new_slopes.py" instead.
#          min(S) = 3.21667903335765e-06
#          max(S) = 0.5583505630493164
# -------------------------------------------------
#
# Imported netCDF4 version: 1.5.7
# EMELI: Initialized component: tf_channels_kin_wave.
#
# Snow component: Initializing...
# Reading config file into component state.
# Snow component: Disabled in CFG file.
# EMELI: Initialized component: tf_snow_degree_day.
#
# Groundwater component: Initializing...
# Reading config file into component state.
# Groundwater component: Disabled in CFG file.
# EMELI: Initialized component: tf_satzone_attenuate.
#
# Evaporation component: Initializing...
# Reading config file into component state.
# Evaporation component: Disabled in CFG file.
# EMELI: Initialized component: tf_evap_priestley_taylor.
#
# Infiltration component: Initializing...
# Reading config file into component state.
# Infiltration component: Disabled in CFG file.
# EMELI: Initialized component: tf_infil_richards_1d.
#
# Ice component: Initializing...
# Reading config file into component state.
# Ice component: Disabled in CFG file.
# EMELI: Initialized component: tf_ice_gc2d.
#
# TopoFlow component: Initializing...
# Reading config file into component state.
# Setting stop method to: Until_model_time
# Opening log file:
#     log_file = /Users/peckhams/TF_Tests/Tana_120sec/Test1.log
# Starting TopoFlow model run...
# EMELI: Initialized component: topoflow_driver.
#
# EMELI: Component time step sizes =
#     tf_meteorology = 21600.0 [seconds]
#     tf_diversions_fraction_method is Disabled.
#     tf_channels_kin_wave = 900.0 [seconds]
#     tf_snow_degree_day is Disabled.
#     tf_satzone_attenuate is Disabled.
#     tf_evap_priestley_taylor is Disabled.
#     tf_infil_richards_1d is Disabled.
#     tf_ice_gc2d is Disabled.
#     topoflow_driver = 100.0 [seconds]
# Converting all time step units to seconds...
# Component with smallest time step is: topoflow_driver
#
# Time interpolation method = Linear
#
# Will print values every 0.5 seconds.
# Time =     600.00 [min],  Q_out =   45.45438 [m^3/s]
# Time =    1260.00 [min],  Q_out =   45.02510 [m^3/s]
# Time =    1980.00 [min],  Q_out =   44.33443 [m^3/s]
# Time =    2655.00 [min],  Q_out =   43.74263 [m^3/s]
# Time =    3420.00 [min],  Q_out =   42.92008 [m^3/s]
# Time =    4140.00 [min],  Q_out =   41.90252 [m^3/s]
# Time =    4875.00 [min],  Q_out =   40.87925 [m^3/s]
# Time =    5565.00 [min],  Q_out =   39.76310 [m^3/s]
# Time =    6270.00 [min],  Q_out =   38.70871 [m^3/s]
# Time =    6975.00 [min],  Q_out =   38.42452 [m^3/s]
# Time =    7695.00 [min],  Q_out =   39.72998 [m^3/s]
# Time =    8420.00 [min],  Q_out =   43.06512 [m^3/s]
# Time =    9180.00 [min],  Q_out =   43.27520 [m^3/s]
# Time =    9870.00 [min],  Q_out =   43.62117 [m^3/s]
# Time =   10563.33 [min],  Q_out =   93.49845 [m^3/s]
# Time =   11250.00 [min],  Q_out =  141.54113 [m^3/s]
# Time =   11970.00 [min],  Q_out =  131.90609 [m^3/s]
# Time =   12720.00 [min],  Q_out =  157.53068 [m^3/s]
# Time =   13485.00 [min],  Q_out =  164.88046 [m^3/s]
# Time =   14265.00 [min],  Q_out =  128.96674 [m^3/s]
# Time =   15015.00 [min],  Q_out =  103.18858 [m^3/s]
# Time =   15765.00 [min],  Q_out =   85.80704 [m^3/s]
# Time =   16545.00 [min],  Q_out =   99.10025 [m^3/s]
# Time =   17280.00 [min],  Q_out =  217.74134 [m^3/s]
# Time =   18015.00 [min],  Q_out =  192.15750 [m^3/s]
# Time =   18765.00 [min],  Q_out =  170.31541 [m^3/s]
# Time =   19545.00 [min],  Q_out =  188.31446 [m^3/s]
# Time =   20295.00 [min],  Q_out =  243.13369 [m^3/s]
# Time =   21045.00 [min],  Q_out =  223.48619 [m^3/s]
# Time =   21750.00 [min],  Q_out =  196.60773 [m^3/s]
# Time =   22455.00 [min],  Q_out =  172.01419 [m^3/s]
# Time =   23190.00 [min],  Q_out =  146.39371 [m^3/s]
# Time =   23910.00 [min],  Q_out =  125.54605 [m^3/s]
# Time =   24630.00 [min],  Q_out =  109.12662 [m^3/s]
# Time =   25335.00 [min],  Q_out =   95.52651 [m^3/s]
# Time =   26070.00 [min],  Q_out =   82.62585 [m^3/s]
# Time =   26790.00 [min],  Q_out =   73.68126 [m^3/s]
# Time =   27510.00 [min],  Q_out =   71.10796 [m^3/s]
# Time =   28230.00 [min],  Q_out =   70.96336 [m^3/s]
# Time =   28965.00 [min],  Q_out =   78.75148 [m^3/s]
# Time =   29670.00 [min],  Q_out =  116.23360 [m^3/s]
# Time =   30375.00 [min],  Q_out =  182.02072 [m^3/s]
# Time =   31125.00 [min],  Q_out =  170.43140 [m^3/s]
# Time =   31845.00 [min],  Q_out =  136.98018 [m^3/s]
# Time =   32571.67 [min],  Q_out =  110.43571 [m^3/s]
# Time =   33315.00 [min],  Q_out =   90.25385 [m^3/s]
# Time =   34095.00 [min],  Q_out =   74.63196 [m^3/s]
# Time =   34875.00 [min],  Q_out =   61.96906 [m^3/s]
# Time =   35655.00 [min],  Q_out =   55.42813 [m^3/s]
# Time =   36435.00 [min],  Q_out =   47.19735 [m^3/s]
# Time =   37155.00 [min],  Q_out =   42.81574 [m^3/s]
# Time =   37890.00 [min],  Q_out =   37.20466 [m^3/s]
# Time =   38610.00 [min],  Q_out =   33.91712 [m^3/s]
# Time =   39345.00 [min],  Q_out =   29.98473 [m^3/s]
# Time =   40071.67 [min],  Q_out =   28.25081 [m^3/s]
# Time =   40800.00 [min],  Q_out =   27.88903 [m^3/s]
# Time =   41520.00 [min],  Q_out =   32.64222 [m^3/s]
# Time =   42285.00 [min],  Q_out =   37.86636 [m^3/s]
# Time =   43005.00 [min],  Q_out =   40.42939 [m^3/s]
# Time =   43766.67 [min],  Q_out =   49.34748 [m^3/s]
# Time =   44505.00 [min],  Q_out =   79.17433 [m^3/s]
# Time =   45240.00 [min],  Q_out =  134.24286 [m^3/s]
# Time =   45945.00 [min],  Q_out =  159.58457 [m^3/s]
# Time =   46650.00 [min],  Q_out =  181.57719 [m^3/s]
# Time =   47355.00 [min],  Q_out =  249.67332 [m^3/s]
# Time =   48073.33 [min],  Q_out =  304.81288 [m^3/s]
# Time =   48810.00 [min],  Q_out =  279.04914 [m^3/s]
# Time =   49590.00 [min],  Q_out =  281.68934 [m^3/s]
# Time =   50370.00 [min],  Q_out =  316.19249 [m^3/s]
# Time =   51135.00 [min],  Q_out =  281.46200 [m^3/s]
# Time =   51915.00 [min],  Q_out =  288.03995 [m^3/s]
# Time =   52695.00 [min],  Q_out =  242.77226 [m^3/s]
# Time =   53460.00 [min],  Q_out =  235.92477 [m^3/s]
# Time =   54225.00 [min],  Q_out =  256.09744 [m^3/s]
# Time =   55011.67 [min],  Q_out =  284.63671 [m^3/s]
# Time =   55785.00 [min],  Q_out =  276.84358 [m^3/s]
# Time =   56565.00 [min],  Q_out =  223.50213 [m^3/s]
# Time =   57330.00 [min],  Q_out =  224.12927 [m^3/s]
# Time =   58095.00 [min],  Q_out =  214.45787 [m^3/s]
# Time =   58845.00 [min],  Q_out =  175.48333 [m^3/s]
# Time =   59575.00 [min],  Q_out =  147.20027 [m^3/s]
# Time =   60360.00 [min],  Q_out =  128.36475 [m^3/s]
# Time =   61155.00 [min],  Q_out =  177.77115 [m^3/s]
# Time =   61905.00 [min],  Q_out =  275.28466 [m^3/s]
# Time =   62685.00 [min],  Q_out =  245.55086 [m^3/s]
# Time =   63450.00 [min],  Q_out =  258.43264 [m^3/s]
# Time =   64230.00 [min],  Q_out =  293.46454 [m^3/s]
# Time =   65010.00 [min],  Q_out =  287.74264 [m^3/s]
# Time =   65745.00 [min],  Q_out =  283.79569 [m^3/s]
# Time =   66480.00 [min],  Q_out =  334.27130 [m^3/s]
# Time =   67245.00 [min],  Q_out =  316.81364 [m^3/s]
# Time =   68010.00 [min],  Q_out =  309.25584 [m^3/s]
# Time =   68775.00 [min],  Q_out =  307.55426 [m^3/s]
# Time =   69525.00 [min],  Q_out =  307.72211 [m^3/s]
# Time =   70260.00 [min],  Q_out =  307.93828 [m^3/s]
# Time =   71010.00 [min],  Q_out =  308.13168 [m^3/s]
# Time =   71775.00 [min],  Q_out =  308.08357 [m^3/s]
# Time =   72540.00 [min],  Q_out =  309.07045 [m^3/s]
# Time =   73251.67 [min],  Q_out =  308.68505 [m^3/s]
# Time =   73995.00 [min],  Q_out =  312.46159 [m^3/s]
# Time =   74670.00 [min],  Q_out =  310.00374 [m^3/s]
# Time =   75420.00 [min],  Q_out =  312.77683 [m^3/s]
# Time =   76140.00 [min],  Q_out =  311.01656 [m^3/s]
# Time =   76875.00 [min],  Q_out =  312.85743 [m^3/s]
# Time =   77601.67 [min],  Q_out =  313.10534 [m^3/s]
# Time =   78315.00 [min],  Q_out =  313.37824 [m^3/s]
# Time =   79050.00 [min],  Q_out =  313.65488 [m^3/s]
# Time =   79755.00 [min],  Q_out =  313.62610 [m^3/s]
# Time =   80490.00 [min],  Q_out =  301.97353 [m^3/s]
# Time =   81240.00 [min],  Q_out =  233.40707 [m^3/s]
# Time =   81960.00 [min],  Q_out =  208.64539 [m^3/s]
# Time =   82740.00 [min],  Q_out =  249.43686 [m^3/s]
# Time =   83490.00 [min],  Q_out =  299.80945 [m^3/s]
# Time =   84246.67 [min],  Q_out =  313.50194 [m^3/s]
# Time =   84990.00 [min],  Q_out =  313.07592 [m^3/s]
# Time =   85725.00 [min],  Q_out =  312.43919 [m^3/s]
# Time =   86505.00 [min],  Q_out =  312.00128 [m^3/s]
# Time =   87268.33 [min],  Q_out =  311.57465 [m^3/s]
# Time =   88005.00 [min],  Q_out =  311.16765 [m^3/s]
# Time =   88770.00 [min],  Q_out =  310.45881 [m^3/s]
# Time =   89536.67 [min],  Q_out =  302.22113 [m^3/s]
# Time =   90300.00 [min],  Q_out =  292.39692 [m^3/s]
# Time =   91050.00 [min],  Q_out =  273.83079 [m^3/s]
# Time =   91755.00 [min],  Q_out =  230.01567 [m^3/s]
# Time =   92505.00 [min],  Q_out =  200.48708 [m^3/s]
# Time =   93255.00 [min],  Q_out =  181.53674 [m^3/s]
# Time =   93960.00 [min],  Q_out =  178.39413 [m^3/s]
# Time =   94680.00 [min],  Q_out =  205.94104 [m^3/s]
# Time =   95445.00 [min],  Q_out =  222.20254 [m^3/s]
# Time =   96210.00 [min],  Q_out =  202.91883 [m^3/s]
# Time =   96945.00 [min],  Q_out =  169.08625 [m^3/s]
# Time =   97710.00 [min],  Q_out =  135.98829 [m^3/s]
# Time =   98490.00 [min],  Q_out =  118.64636 [m^3/s]
# Time =   99255.00 [min],  Q_out =  109.06912 [m^3/s]
# Time =   99976.67 [min],  Q_out =   96.14597 [m^3/s]
# Time =  100665.00 [min],  Q_out =   82.81807 [m^3/s]
# Time =  101340.00 [min],  Q_out =   72.60336 [m^3/s]
# Time =  101985.00 [min],  Q_out =   68.51398 [m^3/s]
# Time =  102705.00 [min],  Q_out =   66.18593 [m^3/s]
# Time =  103470.00 [min],  Q_out =   61.07241 [m^3/s]
# Time =  104235.00 [min],  Q_out =   58.24948 [m^3/s]
# Time =  105000.00 [min],  Q_out =   54.64643 [m^3/s]
# Time =  105780.00 [min],  Q_out =   47.87009 [m^3/s]
# Time =  106516.67 [min],  Q_out =   41.50331 [m^3/s]
# Time =  107280.00 [min],  Q_out =   35.81271 [m^3/s]
# Time =  108015.00 [min],  Q_out =   31.24093 [m^3/s]
# Time =  108795.00 [min],  Q_out =   28.52971 [m^3/s]
# Time =  109575.00 [min],  Q_out =   51.37726 [m^3/s]
# Time =  110340.00 [min],  Q_out =  301.77878 [m^3/s]
# Time =  111120.00 [min],  Q_out =  306.00880 [m^3/s]
# Time =  111885.00 [min],  Q_out =  322.48785 [m^3/s]
# Time =  112665.00 [min],  Q_out =  326.18804 [m^3/s]
# Time =  113415.00 [min],  Q_out =  317.69073 [m^3/s]
# Time =  114120.00 [min],  Q_out =  296.82468 [m^3/s]
# Time =  114825.00 [min],  Q_out =  287.86135 [m^3/s]
# Time =  115590.00 [min],  Q_out =  295.46238 [m^3/s]
# Time =  116370.00 [min],  Q_out =  307.71113 [m^3/s]
# Time =  117090.00 [min],  Q_out =  307.60402 [m^3/s]
# Time =  117813.33 [min],  Q_out =  307.40664 [m^3/s]
# Time =  118560.00 [min],  Q_out =  307.20143 [m^3/s]
# Time =  119265.00 [min],  Q_out =  301.54676 [m^3/s]
# Time =  120015.00 [min],  Q_out =  250.71363 [m^3/s]
# Time =  120735.00 [min],  Q_out =  205.38902 [m^3/s]
# Time =  121440.00 [min],  Q_out =  167.91866 [m^3/s]
# Time =  122145.00 [min],  Q_out =  137.27180 [m^3/s]
# Time =  122880.00 [min],  Q_out =  112.33255 [m^3/s]
# Time =  123615.00 [min],  Q_out =   93.18444 [m^3/s]
# Time =  124348.33 [min],  Q_out =   77.66672 [m^3/s]
# Time =  125070.00 [min],  Q_out =   65.88502 [m^3/s]
# Time =  125805.00 [min],  Q_out =   56.34006 [m^3/s]
# Time =  126525.00 [min],  Q_out =   51.35663 [m^3/s]
# Time =  127260.00 [min],  Q_out =   45.47061 [m^3/s]
# Time =  128040.00 [min],  Q_out =   39.11624 [m^3/s]
# Time =  128760.00 [min],  Q_out =   34.29903 [m^3/s]
# Time =  129495.00 [min],  Q_out =   30.68346 [m^3/s]
# Time =  130200.00 [min],  Q_out =   28.26205 [m^3/s]
# Time =  130920.00 [min],  Q_out =   26.06231 [m^3/s]
# Time =  131670.00 [min],  Q_out =   23.55539 [m^3/s]
# Time =  132405.00 [min],  Q_out =   22.58122 [m^3/s]
# Time =  133155.00 [min],  Q_out =   23.94701 [m^3/s]
# Time =  133875.00 [min],  Q_out =   23.42997 [m^3/s]
# Time =  134580.00 [min],  Q_out =   21.62841 [m^3/s]
# Time =  135315.00 [min],  Q_out =   21.94291 [m^3/s]
# Time =  136065.00 [min],  Q_out =   27.12451 [m^3/s]
# Time =  136815.00 [min],  Q_out =   28.53823 [m^3/s]
# Time =  137595.00 [min],  Q_out =   26.06689 [m^3/s]
# Time =  138360.00 [min],  Q_out =   23.02310 [m^3/s]
# Time =  139110.00 [min],  Q_out =   20.43651 [m^3/s]
# Time =  139845.00 [min],  Q_out =   18.30965 [m^3/s]
# Time =  140610.00 [min],  Q_out =   16.48510 [m^3/s]
# Time =  141356.67 [min],  Q_out =   15.01004 [m^3/s]
# Time =  142110.00 [min],  Q_out =   13.75374 [m^3/s]
# Time =  142845.00 [min],  Q_out =   12.66562 [m^3/s]
# Time =  143595.00 [min],  Q_out =   11.75831 [m^3/s]
# Time =  144300.00 [min],  Q_out =   11.90302 [m^3/s]
# Time =  145050.00 [min],  Q_out =   14.21681 [m^3/s]
# Time =  145800.00 [min],  Q_out =   15.87123 [m^3/s]
# Time =  146520.00 [min],  Q_out =   82.80008 [m^3/s]
# Time =  147285.00 [min],  Q_out =  101.20153 [m^3/s]
# Time =  148020.00 [min],  Q_out =   84.51568 [m^3/s]
# Time =  148770.00 [min],  Q_out =   84.44932 [m^3/s]
# Time =  149505.00 [min],  Q_out =  141.11470 [m^3/s]
# Time =  150255.00 [min],  Q_out =  220.84956 [m^3/s]
# Time =  151001.67 [min],  Q_out =  219.84826 [m^3/s]
# Time =  151620.00 [min],  Q_out =  183.47323 [m^3/s]
# Time =  152355.00 [min],  Q_out =  152.52165 [m^3/s]
# Time =  153135.00 [min],  Q_out =  158.47806 [m^3/s]
# Time =  153900.00 [min],  Q_out =  138.69050 [m^3/s]
# Time =  154635.00 [min],  Q_out =  113.80170 [m^3/s]
# Time =  155370.00 [min],  Q_out =   93.35529 [m^3/s]
# Time =  156135.00 [min],  Q_out =   77.28649 [m^3/s]
# Time =  156900.00 [min],  Q_out =   65.09170 [m^3/s]
# Time =  157680.00 [min],  Q_out =   55.46600 [m^3/s]
# Time =  158445.00 [min],  Q_out =   48.09132 [m^3/s]
# Time =  159176.67 [min],  Q_out =   42.53707 [m^3/s]
# Time =  159930.00 [min],  Q_out =   37.94157 [m^3/s]
# Time =  160680.00 [min],  Q_out =   34.03808 [m^3/s]
# Time =  161420.00 [min],  Q_out =   30.65545 [m^3/s]
# Time =  162150.00 [min],  Q_out =   27.59333 [m^3/s]
# Time =  162840.00 [min],  Q_out =   25.04565 [m^3/s]
# Time =  163575.00 [min],  Q_out =   22.76753 [m^3/s]
# Time =  164325.00 [min],  Q_out =   21.10193 [m^3/s]
# Time =  165090.00 [min],  Q_out =   22.42974 [m^3/s]
# Time =  165855.00 [min],  Q_out =   67.73150 [m^3/s]
# Time =  166600.00 [min],  Q_out =  100.17363 [m^3/s]
# Time =  167340.00 [min],  Q_out =   95.48498 [m^3/s]
# Time =  168105.00 [min],  Q_out =   91.34601 [m^3/s]
# Time =  168843.33 [min],  Q_out =  101.53392 [m^3/s]
# Time =  169605.00 [min],  Q_out =   96.99389 [m^3/s]
# Time =  170355.00 [min],  Q_out =   83.00758 [m^3/s]
# Time =  171105.00 [min],  Q_out =   70.16551 [m^3/s]
# Time =  171855.00 [min],  Q_out =   60.50028 [m^3/s]
# Time =  172605.00 [min],  Q_out =   53.71340 [m^3/s]
# Time =  173355.00 [min],  Q_out =   48.60812 [m^3/s]
# Time =  174120.00 [min],  Q_out =   44.19994 [m^3/s]
# Time =  174900.00 [min],  Q_out =   40.17258 [m^3/s]
# Time =  175665.00 [min],  Q_out =   35.84931 [m^3/s]
# Time =  176430.00 [min],  Q_out =   31.43413 [m^3/s]
# Time =  177180.00 [min],  Q_out =   27.55161 [m^3/s]
# Time =  177945.00 [min],  Q_out =   24.15167 [m^3/s]
# Time =  178665.00 [min],  Q_out =   21.42884 [m^3/s]
# Time =  179385.00 [min],  Q_out =   19.11786 [m^3/s]
# Time =  180150.00 [min],  Q_out =   17.06105 [m^3/s]
# Time =  180885.00 [min],  Q_out =   26.85061 [m^3/s]
# Time =  181620.00 [min],  Q_out =   65.68911 [m^3/s]
# Time =  182355.00 [min],  Q_out =   66.61940 [m^3/s]
# Time =  183105.00 [min],  Q_out =   60.44186 [m^3/s]
# Time =  183855.00 [min],  Q_out =   52.66933 [m^3/s]
# Time =  184605.00 [min],  Q_out =   45.70820 [m^3/s]
# Time =  185385.00 [min],  Q_out =   40.03040 [m^3/s]
# Time =  186150.00 [min],  Q_out =   35.77098 [m^3/s]
# Time =  186915.00 [min],  Q_out =   32.14048 [m^3/s]
# Time =  187665.00 [min],  Q_out =   28.82252 [m^3/s]
# Time =  188411.67 [min],  Q_out =   25.76184 [m^3/s]
# Time =  189150.00 [min],  Q_out =   23.02960 [m^3/s]
# Time =  189891.67 [min],  Q_out =   20.60421 [m^3/s]
# Time =  190650.00 [min],  Q_out =   18.44907 [m^3/s]
# Time =  191400.00 [min],  Q_out =   16.61686 [m^3/s]
# Time =  192135.00 [min],  Q_out =   15.07490 [m^3/s]
# Time =  192825.00 [min],  Q_out =   13.81742 [m^3/s]
# Time =  193575.00 [min],  Q_out =   12.61625 [m^3/s]
# Time =  194316.67 [min],  Q_out =   11.56452 [m^3/s]
# Time =  195045.00 [min],  Q_out =   10.65266 [m^3/s]
# Time =  195780.00 [min],  Q_out =   12.62515 [m^3/s]
# Time =  196515.00 [min],  Q_out =   23.18111 [m^3/s]
# Time =  197280.00 [min],  Q_out =   28.16246 [m^3/s]
# Time =  198045.00 [min],  Q_out =   80.43335 [m^3/s]
# Time =  198795.00 [min],  Q_out =  104.63716 [m^3/s]
# Time =  199500.00 [min],  Q_out =   91.98784 [m^3/s]
# Time =  200235.00 [min],  Q_out =   78.31815 [m^3/s]
# Time =  200985.00 [min],  Q_out =   66.33761 [m^3/s]
# Time =  201705.00 [min],  Q_out =   56.81168 [m^3/s]
# Time =  202448.33 [min],  Q_out =   48.72252 [m^3/s]
# Time =  203175.00 [min],  Q_out =   42.37475 [m^3/s]
# Time =  203903.33 [min],  Q_out =   37.24999 [m^3/s]
# Time =  204630.00 [min],  Q_out =   33.00527 [m^3/s]
# Time =  205365.00 [min],  Q_out =   29.31751 [m^3/s]
# Time =  206085.00 [min],  Q_out =   26.21137 [m^3/s]
# Time =  206850.00 [min],  Q_out =   23.37195 [m^3/s]
# Time =  207495.00 [min],  Q_out =   21.36902 [m^3/s]
# Time =  208215.00 [min],  Q_out =   19.72726 [m^3/s]
# Time =  208920.00 [min],  Q_out =   18.82388 [m^3/s]
# Time =  209655.00 [min],  Q_out =   20.19828 [m^3/s]
# Time =  210390.00 [min],  Q_out =   26.00543 [m^3/s]
# Time =  211125.00 [min],  Q_out =   30.45222 [m^3/s]
# Time =  211800.00 [min],  Q_out =   30.66703 [m^3/s]
# Time =  212550.00 [min],  Q_out =   28.61430 [m^3/s]
# Time =  213285.00 [min],  Q_out =   27.49959 [m^3/s]
# Time =  214020.00 [min],  Q_out =   30.68136 [m^3/s]
# Time =  214755.00 [min],  Q_out =   33.47206 [m^3/s]
# Time =  215505.00 [min],  Q_out =   35.30110 [m^3/s]
# Time =  216225.00 [min],  Q_out =   38.00074 [m^3/s]
# Time =  216930.00 [min],  Q_out =   35.62803 [m^3/s]
# Time =  217635.00 [min],  Q_out =   32.19148 [m^3/s]
# Time =  218385.00 [min],  Q_out =   37.12209 [m^3/s]
# Time =  219090.00 [min],  Q_out =   53.86371 [m^3/s]
# Time =  219805.00 [min],  Q_out =   66.55124 [m^3/s]
# Time =  220515.00 [min],  Q_out =   71.18696 [m^3/s]
# Time =  221255.00 [min],  Q_out =   67.04638 [m^3/s]
# Time =  221960.00 [min],  Q_out =   60.62623 [m^3/s]
# Time =  222705.00 [min],  Q_out =   53.01617 [m^3/s]
# Time =  223440.00 [min],  Q_out =   45.84673 [m^3/s]
# Time =  224175.00 [min],  Q_out =   40.60886 [m^3/s]
# Time =  224820.00 [min],  Q_out =   38.02452 [m^3/s]
# Time =  225555.00 [min],  Q_out =   35.67267 [m^3/s]
# Time =  226275.00 [min],  Q_out =   32.61571 [m^3/s]
# Time =  227010.00 [min],  Q_out =   29.29017 [m^3/s]
# Time =  227730.00 [min],  Q_out =   26.53114 [m^3/s]
# Time =  228420.00 [min],  Q_out =   24.95420 [m^3/s]
# Time =  229080.00 [min],  Q_out =   27.19515 [m^3/s]
# Time =  229800.00 [min],  Q_out =   34.27576 [m^3/s]
# Time =  230550.00 [min],  Q_out =   38.46221 [m^3/s]
# Time =  231300.00 [min],  Q_out =   46.52448 [m^3/s]
# Time =  232056.67 [min],  Q_out =   72.15151 [m^3/s]
# Time =  232800.00 [min],  Q_out =   96.68506 [m^3/s]
# Time =  233565.00 [min],  Q_out =   97.07443 [m^3/s]
# Time =  234330.00 [min],  Q_out =  173.09290 [m^3/s]
# Time =  235080.00 [min],  Q_out =  238.55625 [m^3/s]
# Time =  235830.00 [min],  Q_out =  300.58245 [m^3/s]
# Time =  236595.00 [min],  Q_out =  304.77905 [m^3/s]
# Time =  237360.00 [min],  Q_out =  304.75231 [m^3/s]
# Time =  238110.00 [min],  Q_out =  297.43370 [m^3/s]
# Time =  238875.00 [min],  Q_out =  243.93888 [m^3/s]
# Time =  239625.00 [min],  Q_out =  191.10590 [m^3/s]
# Time =  240360.00 [min],  Q_out =  154.40394 [m^3/s]
# Time =  241125.00 [min],  Q_out =  126.79212 [m^3/s]
# Time =  241905.00 [min],  Q_out =  104.94188 [m^3/s]
# Time =  242670.00 [min],  Q_out =   87.55178 [m^3/s]
# Time =  243435.00 [min],  Q_out =   73.44694 [m^3/s]
# Time =  244200.00 [min],  Q_out =   62.08431 [m^3/s]
# Time =  244965.00 [min],  Q_out =   52.92760 [m^3/s]
# Time =  245745.00 [min],  Q_out =   45.37655 [m^3/s]
# Time =  246510.00 [min],  Q_out =   39.33706 [m^3/s]
# Time =  247275.00 [min],  Q_out =   34.36805 [m^3/s]
# Time =  248040.00 [min],  Q_out =   30.31051 [m^3/s]
# Time =  248805.00 [min],  Q_out =   27.14607 [m^3/s]
# Time =  249570.00 [min],  Q_out =   24.60187 [m^3/s]
# Time =  250335.00 [min],  Q_out =   22.32771 [m^3/s]
# Time =  251040.00 [min],  Q_out =   20.53942 [m^3/s]
# Time =  251790.00 [min],  Q_out =   19.14904 [m^3/s]
# Time =  252480.00 [min],  Q_out =   18.35340 [m^3/s]
# Time =  253200.00 [min],  Q_out =   17.70630 [m^3/s]
# Time =  253931.67 [min],  Q_out =   16.81189 [m^3/s]
# Time =  254625.00 [min],  Q_out =   15.67565 [m^3/s]
# Time =  255351.67 [min],  Q_out =   14.37326 [m^3/s]
# Time =  256065.00 [min],  Q_out =   13.16696 [m^3/s]
# Time =  256785.00 [min],  Q_out =   12.09866 [m^3/s]
# Time =  257505.00 [min],  Q_out =   11.14958 [m^3/s]
# Time =  258240.00 [min],  Q_out =   10.25899 [m^3/s]
# Time =  259005.00 [min],  Q_out =    9.41211 [m^3/s]
# Time =  259770.00 [min],  Q_out =    8.65334 [m^3/s]
# Time =  260520.00 [min],  Q_out =    7.99359 [m^3/s]
# Time =  261270.00 [min],  Q_out =    7.40942 [m^3/s]
# Time =  262005.00 [min],  Q_out =    6.90092 [m^3/s]
# Time =  262755.00 [min],  Q_out =    6.43825 [m^3/s]
# Time =  263505.00 [min],  Q_out =    6.02443 [m^3/s]
# Time =  264255.00 [min],  Q_out =    5.65291 [m^3/s]
# Time =  264990.00 [min],  Q_out =    5.32388 [m^3/s]
# Time =  265733.33 [min],  Q_out =    5.02140 [m^3/s]
# Time =  266475.00 [min],  Q_out =    4.74628 [m^3/s]
# Time =  267210.00 [min],  Q_out =    4.49968 [m^3/s]
# Time =  267923.33 [min],  Q_out =    4.36457 [m^3/s]
# Time =  268680.00 [min],  Q_out =    4.77380 [m^3/s]
# Time =  269430.00 [min],  Q_out =   19.20929 [m^3/s]
# Time =  270165.00 [min],  Q_out =  100.20434 [m^3/s]
# Time =  270915.00 [min],  Q_out =  167.67942 [m^3/s]
# Time =  271665.00 [min],  Q_out =  255.52891 [m^3/s]
# Time =  272370.00 [min],  Q_out =  250.70512 [m^3/s]
# Time =  273075.00 [min],  Q_out =  250.43781 [m^3/s]
# Time =  273780.00 [min],  Q_out =  256.74526 [m^3/s]
# Time =  274485.00 [min],  Q_out =  304.26306 [m^3/s]
# Time =  275175.00 [min],  Q_out =  304.04853 [m^3/s]
# Time =  275895.00 [min],  Q_out =  277.78320 [m^3/s]
# Time =  276600.00 [min],  Q_out =  238.70419 [m^3/s]
# Time =  277230.00 [min],  Q_out =  215.34855 [m^3/s]
# Time =  277920.00 [min],  Q_out =  191.64710 [m^3/s]
# Time =  278625.00 [min],  Q_out =  163.17899 [m^3/s]
# Time =  279330.00 [min],  Q_out =  143.13535 [m^3/s]
# Time =  279941.67 [min],  Q_out =  131.65616 [m^3/s]
# Time =  280590.00 [min],  Q_out =  125.09830 [m^3/s]
# Time =  281265.00 [min],  Q_out =  120.48396 [m^3/s]
# Time =  282000.00 [min],  Q_out =  109.88970 [m^3/s]
# Time =  282765.00 [min],  Q_out =   98.32192 [m^3/s]
# Time =  283530.00 [min],  Q_out =  137.00537 [m^3/s]
# Time =  284291.67 [min],  Q_out =  159.50812 [m^3/s]
# Time =  285045.00 [min],  Q_out =  138.89251 [m^3/s]
# Time =  285808.33 [min],  Q_out =  135.40222 [m^3/s]
# Time =  286560.00 [min],  Q_out =  130.89231 [m^3/s]
# Time =  287325.00 [min],  Q_out =  123.33016 [m^3/s]
# Time =  288090.00 [min],  Q_out =  104.88514 [m^3/s]
# Time =  288840.00 [min],  Q_out =  123.38099 [m^3/s]
# Time =  289605.00 [min],  Q_out =  137.57659 [m^3/s]
# Time =  290370.00 [min],  Q_out =  127.75590 [m^3/s]
# Time =  291120.00 [min],  Q_out =  105.46497 [m^3/s]
# Time =  291885.00 [min],  Q_out =  105.08539 [m^3/s]
# Time =  292650.00 [min],  Q_out =  183.16951 [m^3/s]
# Time =  293370.00 [min],  Q_out =  176.10877 [m^3/s]
# Time =  294135.00 [min],  Q_out =  290.43566 [m^3/s]
# Time =  294855.00 [min],  Q_out =  304.93979 [m^3/s]
# Time =  295620.00 [min],  Q_out =  305.03680 [m^3/s]
# Time =  296360.00 [min],  Q_out =  305.03789 [m^3/s]
# Time =  297135.00 [min],  Q_out =  305.32517 [m^3/s]
# Time =  297900.00 [min],  Q_out =  292.95565 [m^3/s]
# Time =  298658.33 [min],  Q_out =  249.65540 [m^3/s]
# Time =  299415.00 [min],  Q_out =  211.87762 [m^3/s]
# Time =  300180.00 [min],  Q_out =  256.45526 [m^3/s]
# Time =  300945.00 [min],  Q_out =  300.30211 [m^3/s]
# Time =  301711.67 [min],  Q_out =  295.75398 [m^3/s]
# Time =  302475.00 [min],  Q_out =  279.39223 [m^3/s]
# Time =  303240.00 [min],  Q_out =  273.03905 [m^3/s]
# Time =  304005.00 [min],  Q_out =  242.61872 [m^3/s]
# Time =  304770.00 [min],  Q_out =  196.29406 [m^3/s]
# Time =  305535.00 [min],  Q_out =  166.41606 [m^3/s]
# Time =  306293.33 [min],  Q_out =  146.62265 [m^3/s]
# Time =  307050.00 [min],  Q_out =  227.51650 [m^3/s]
# Time =  307800.00 [min],  Q_out =  248.95480 [m^3/s]
# Time =  308520.00 [min],  Q_out =  258.45083 [m^3/s]
# Time =  309240.00 [min],  Q_out =  257.01436 [m^3/s]
# Time =  309960.00 [min],  Q_out =  258.26471 [m^3/s]
# Time =  310701.67 [min],  Q_out =  257.74251 [m^3/s]
# Time =  311385.00 [min],  Q_out =  254.10251 [m^3/s]
# Time =  312060.00 [min],  Q_out =  252.63270 [m^3/s]
# Time =  312750.00 [min],  Q_out =  253.51102 [m^3/s]
# Time =  313451.67 [min],  Q_out =  253.69014 [m^3/s]
# Time =  314100.00 [min],  Q_out =  242.89137 [m^3/s]
# Time =  314760.00 [min],  Q_out =  223.18770 [m^3/s]
# Time =  315430.00 [min],  Q_out =  192.44664 [m^3/s]
# Time =  316095.00 [min],  Q_out =  161.21368 [m^3/s]
# Time =  316785.00 [min],  Q_out =  135.74900 [m^3/s]
# Time =  317445.00 [min],  Q_out =  165.30467 [m^3/s]
# Time =  318105.00 [min],  Q_out =  250.41322 [m^3/s]
# Time =  318765.00 [min],  Q_out =  231.49216 [m^3/s]
# Time =  319425.00 [min],  Q_out =  168.17946 [m^3/s]
# Time =  320100.00 [min],  Q_out =  120.86924 [m^3/s]
# Time =  320800.00 [min],  Q_out =   98.15951 [m^3/s]
# Time =  321540.00 [min],  Q_out =   83.40732 [m^3/s]
# Time =  322245.00 [min],  Q_out =   74.79371 [m^3/s]
# Time =  322995.00 [min],  Q_out =   75.94256 [m^3/s]
# Time =  323760.00 [min],  Q_out =   79.35371 [m^3/s]
# Time =  324480.00 [min],  Q_out =   71.21564 [m^3/s]
# Time =  325125.00 [min],  Q_out =   63.34163 [m^3/s]
# Time =  325830.00 [min],  Q_out =   57.92034 [m^3/s]
# Time =  326550.00 [min],  Q_out =   54.81605 [m^3/s]
# Time =  327300.00 [min],  Q_out =   51.32239 [m^3/s]
# Time =  328035.00 [min],  Q_out =   48.11959 [m^3/s]
# Time =  328755.00 [min],  Q_out =   46.18243 [m^3/s]
# Time =  329490.00 [min],  Q_out =   43.91958 [m^3/s]
# Time =  330210.00 [min],  Q_out =   40.64271 [m^3/s]
# Time =  330915.00 [min],  Q_out =   37.84445 [m^3/s]
# Time =  331590.00 [min],  Q_out =   37.06229 [m^3/s]
# Time =  332250.00 [min],  Q_out =   36.33937 [m^3/s]
# Time =  332925.00 [min],  Q_out =   34.98748 [m^3/s]
# Time =  333570.00 [min],  Q_out =   33.33048 [m^3/s]
# Time =  334200.00 [min],  Q_out =   30.84382 [m^3/s]
# Time =  334845.00 [min],  Q_out =   28.02980 [m^3/s]
# Time =  335510.00 [min],  Q_out =   25.46755 [m^3/s]
# Time =  336195.00 [min],  Q_out =   23.48464 [m^3/s]
# Time =  336825.00 [min],  Q_out =   22.30905 [m^3/s]
# Time =  337470.00 [min],  Q_out =   21.63885 [m^3/s]
# Time =  338100.00 [min],  Q_out =   21.19446 [m^3/s]
# Time =  338730.00 [min],  Q_out =   20.57635 [m^3/s]
# Time =  339360.00 [min],  Q_out =   20.12710 [m^3/s]
# Time =  340000.00 [min],  Q_out =   21.35908 [m^3/s]
# Time =  340610.00 [min],  Q_out =   23.57204 [m^3/s]
# Time =  341250.00 [min],  Q_out =   24.78883 [m^3/s]
# Time =  341880.00 [min],  Q_out =   24.69600 [m^3/s]
# Time =  342553.33 [min],  Q_out =   38.47465 [m^3/s]
# Time =  343200.00 [min],  Q_out =   52.14850 [m^3/s]
# Time =  343845.00 [min],  Q_out =   49.58649 [m^3/s]
# Time =  344520.00 [min],  Q_out =   44.33260 [m^3/s]
# Time =  345178.33 [min],  Q_out =   39.73520 [m^3/s]
# Time =  345780.00 [min],  Q_out =   36.14658 [m^3/s]
# Time =  346455.00 [min],  Q_out =   32.87460 [m^3/s]
# Time =  347145.00 [min],  Q_out =   30.15698 [m^3/s]
# Time =  347848.33 [min],  Q_out =   27.02683 [m^3/s]
# Time =  348503.33 [min],  Q_out =   25.57136 [m^3/s]
# Time =  349111.67 [min],  Q_out =   24.04833 [m^3/s]
# Time =  349770.00 [min],  Q_out =   21.50634 [m^3/s]
# Time =  350445.00 [min],  Q_out =   20.40130 [m^3/s]
# Time =  351106.67 [min],  Q_out =   19.24377 [m^3/s]
# Time =  351766.67 [min],  Q_out =   19.53679 [m^3/s]
# Time =  352395.00 [min],  Q_out =   21.16135 [m^3/s]
# Time =  353025.00 [min],  Q_out =   24.43195 [m^3/s]
# Time =  353665.00 [min],  Q_out =   29.03437 [m^3/s]
# Time =  354315.00 [min],  Q_out =   32.19907 [m^3/s]
# Time =  354960.00 [min],  Q_out =   36.00110 [m^3/s]
# Time =  355620.00 [min],  Q_out =   45.57900 [m^3/s]
# Time =  356265.00 [min],  Q_out =   53.79832 [m^3/s]
# Time =  356895.00 [min],  Q_out =   54.37505 [m^3/s]
# Time =  357556.67 [min],  Q_out =   51.94479 [m^3/s]
# Time =  358200.00 [min],  Q_out =   50.33195 [m^3/s]
# Time =  358890.00 [min],  Q_out =   49.76673 [m^3/s]
# Time =  359580.00 [min],  Q_out =   52.44646 [m^3/s]
# Time =  360195.00 [min],  Q_out =   52.91401 [m^3/s]
# Time =  360885.00 [min],  Q_out =   49.42888 [m^3/s]
# Time =  361535.00 [min],  Q_out =   44.63693 [m^3/s]
# Time =  362226.67 [min],  Q_out =   40.60878 [m^3/s]
# Time =  362880.00 [min],  Q_out =   38.69618 [m^3/s]
# Time =  363540.00 [min],  Q_out =   35.99667 [m^3/s]
# Time =  364215.00 [min],  Q_out =   32.17139 [m^3/s]
# Time =  364886.67 [min],  Q_out =   28.82548 [m^3/s]
# Time =  365520.00 [min],  Q_out =   28.47969 [m^3/s]
# Time =  366180.00 [min],  Q_out =   34.01455 [m^3/s]
# Time =  366825.00 [min],  Q_out =   53.80275 [m^3/s]
# Time =  367485.00 [min],  Q_out =   92.42998 [m^3/s]
# Time =  368160.00 [min],  Q_out =   97.34388 [m^3/s]
# Time =  368865.00 [min],  Q_out =   88.27746 [m^3/s]
# Time =  369631.67 [min],  Q_out =   77.08861 [m^3/s]
# Time =  370363.33 [min],  Q_out =   68.24428 [m^3/s]
# Time =  371086.67 [min],  Q_out =   59.96683 [m^3/s]
# Time =  371850.00 [min],  Q_out =   51.81914 [m^3/s]
# Time =  372585.00 [min],  Q_out =   45.03120 [m^3/s]
# Time =  373350.00 [min],  Q_out =   41.31891 [m^3/s]
# Time =  374115.00 [min],  Q_out =   39.76871 [m^3/s]
# Time =  374880.00 [min],  Q_out =   36.73356 [m^3/s]
# Time =  375585.00 [min],  Q_out =   32.73890 [m^3/s]
# Time =  376285.00 [min],  Q_out =   29.01603 [m^3/s]
# Time =  376890.00 [min],  Q_out =   26.24810 [m^3/s]
# Time =  377550.00 [min],  Q_out =   24.81176 [m^3/s]
# Time =  378225.00 [min],  Q_out =   25.92228 [m^3/s]
# Time =  378930.00 [min],  Q_out =   41.44402 [m^3/s]
# Time =  379620.00 [min],  Q_out =   54.38257 [m^3/s]
# Time =  380325.00 [min],  Q_out =   47.34996 [m^3/s]
# Time =  381025.00 [min],  Q_out =   41.62469 [m^3/s]
# Time =  381720.00 [min],  Q_out =   37.64328 [m^3/s]
# Time =  382380.00 [min],  Q_out =   37.47674 [m^3/s]
# Time =  383040.00 [min],  Q_out =   39.43790 [m^3/s]
# Time =  383715.00 [min],  Q_out =   38.43464 [m^3/s]
# Time =  384375.00 [min],  Q_out =   35.01469 [m^3/s]
# Time =  385035.00 [min],  Q_out =   31.09214 [m^3/s]
# Time =  385710.00 [min],  Q_out =   27.39908 [m^3/s]
# Time =  386370.00 [min],  Q_out =   24.89128 [m^3/s]
# Time =  387075.00 [min],  Q_out =   24.32846 [m^3/s]
# Time =  387765.00 [min],  Q_out =   26.75103 [m^3/s]
# Time =  388455.00 [min],  Q_out =   35.72281 [m^3/s]
# Time =  389160.00 [min],  Q_out =   50.32064 [m^3/s]
# Time =  389865.00 [min],  Q_out =   62.68315 [m^3/s]
# Time =  390528.33 [min],  Q_out =   63.89196 [m^3/s]
# Time =  391200.00 [min],  Q_out =   70.14644 [m^3/s]
# Time =  391890.00 [min],  Q_out =   74.40701 [m^3/s]
# Time =  392575.00 [min],  Q_out =   68.16121 [m^3/s]
# Time =  393255.00 [min],  Q_out =   60.95170 [m^3/s]
# Time =  393930.00 [min],  Q_out =   54.57492 [m^3/s]
# Time =  394613.33 [min],  Q_out =   48.30910 [m^3/s]
# Time =  395295.00 [min],  Q_out =   42.44603 [m^3/s]
# Time =  395981.67 [min],  Q_out =   37.28385 [m^3/s]
# Time =  396675.00 [min],  Q_out =   32.89899 [m^3/s]
# Time =  397365.00 [min],  Q_out =   29.27469 [m^3/s]
# Time =  398055.00 [min],  Q_out =   26.32214 [m^3/s]
# Time =  398760.00 [min],  Q_out =   24.11234 [m^3/s]
# Time =  399440.00 [min],  Q_out =   22.59423 [m^3/s]
# Time =  400125.00 [min],  Q_out =   21.27879 [m^3/s]
# Time =  400815.00 [min],  Q_out =   20.03319 [m^3/s]
# Time =  401505.00 [min],  Q_out =   18.83233 [m^3/s]
# Time =  402195.00 [min],  Q_out =   17.65105 [m^3/s]
# Time =  402885.00 [min],  Q_out =   16.48277 [m^3/s]
# Time =  403563.33 [min],  Q_out =   15.37135 [m^3/s]
# Time =  404250.00 [min],  Q_out =   14.33057 [m^3/s]
# Time =  404940.00 [min],  Q_out =   13.41346 [m^3/s]
# Time =  405630.00 [min],  Q_out =   12.62334 [m^3/s]
# Time =  406305.00 [min],  Q_out =   11.90331 [m^3/s]
# Time =  406980.00 [min],  Q_out =   11.22179 [m^3/s]
# Time =  407655.00 [min],  Q_out =   10.92717 [m^3/s]
# Time =  408345.00 [min],  Q_out =   13.73897 [m^3/s]
# Time =  409020.00 [min],  Q_out =   20.28154 [m^3/s]
# Time =  409695.00 [min],  Q_out =   28.02182 [m^3/s]
# Time =  410400.00 [min],  Q_out =   34.71393 [m^3/s]
# Time =  411150.00 [min],  Q_out =   37.61129 [m^3/s]
# Time =  411915.00 [min],  Q_out =   37.04852 [m^3/s]
# Time =  412680.00 [min],  Q_out =   34.39179 [m^3/s]
# Time =  413460.00 [min],  Q_out =   31.34012 [m^3/s]
# Time =  414223.33 [min],  Q_out =   30.90232 [m^3/s]
# Time =  414960.00 [min],  Q_out =   32.98856 [m^3/s]
# Time =  415725.00 [min],  Q_out =   32.87799 [m^3/s]
# Time =  416460.00 [min],  Q_out =   30.74399 [m^3/s]
# Time =  417150.00 [min],  Q_out =   28.36285 [m^3/s]
# Time =  417795.00 [min],  Q_out =   26.50980 [m^3/s]
# Time =  418455.00 [min],  Q_out =   25.31162 [m^3/s]
# Time =  419145.00 [min],  Q_out =   26.14183 [m^3/s]
# Time =  419820.00 [min],  Q_out =   37.05564 [m^3/s]
# Time =  420495.00 [min],  Q_out =   51.07437 [m^3/s]
# Time =  421185.00 [min],  Q_out =   58.50859 [m^3/s]
# Time =  421868.33 [min],  Q_out =   59.04729 [m^3/s]
# Time =  422535.00 [min],  Q_out =   54.84553 [m^3/s]
# Time =  423210.00 [min],  Q_out =   48.50820 [m^3/s]
# Time =  423900.00 [min],  Q_out =   42.09390 [m^3/s]
# Time =  424590.00 [min],  Q_out =   36.51817 [m^3/s]
# Time =  425280.00 [min],  Q_out =   32.03194 [m^3/s]
# Time =  425955.00 [min],  Q_out =   28.97363 [m^3/s]
# Time =  426645.00 [min],  Q_out =   26.62309 [m^3/s]
# Time =  427335.00 [min],  Q_out =   24.28761 [m^3/s]
# Time =  428040.00 [min],  Q_out =   22.21849 [m^3/s]
# Time =  428745.00 [min],  Q_out =   20.77347 [m^3/s]
# Time =  429450.00 [min],  Q_out =   21.25513 [m^3/s]
# Time =  430125.00 [min],  Q_out =   23.31076 [m^3/s]
# Time =  430770.00 [min],  Q_out =   27.56616 [m^3/s]
# Time =  431423.33 [min],  Q_out =   35.12119 [m^3/s]
# Time =  432075.00 [min],  Q_out =   46.84831 [m^3/s]
# Time =  432735.00 [min],  Q_out =   56.47980 [m^3/s]
# Time =  433410.00 [min],  Q_out =   58.64800 [m^3/s]
# Time =  434100.00 [min],  Q_out =   56.99801 [m^3/s]
# Time =  434775.00 [min],  Q_out =   52.21214 [m^3/s]
# Time =  435465.00 [min],  Q_out =   48.09963 [m^3/s]
# Time =  436128.33 [min],  Q_out =   43.26660 [m^3/s]
# Time =  436800.00 [min],  Q_out =   37.54508 [m^3/s]
# Time =  437445.00 [min],  Q_out =   32.50656 [m^3/s]
# Time =  438105.00 [min],  Q_out =   28.19543 [m^3/s]
# Time =  438783.33 [min],  Q_out =   24.63884 [m^3/s]
# Time =  439460.00 [min],  Q_out =   21.97840 [m^3/s]
# Time =  440145.00 [min],  Q_out =   20.42177 [m^3/s]
# Time =  440828.33 [min],  Q_out =   20.53216 [m^3/s]
# Time =  441525.00 [min],  Q_out =   22.35114 [m^3/s]
# Time =  442230.00 [min],  Q_out =   24.63430 [m^3/s]
# Time =  442920.00 [min],  Q_out =   26.99729 [m^3/s]
# Time =  443610.00 [min],  Q_out =   31.41447 [m^3/s]
# Time =  444300.00 [min],  Q_out =   35.79025 [m^3/s]
# Time =  444990.00 [min],  Q_out =   35.24285 [m^3/s]
# Time =  445680.00 [min],  Q_out =   33.63924 [m^3/s]
# Time =  446385.00 [min],  Q_out =   36.70344 [m^3/s]
# Time =  447055.00 [min],  Q_out =   48.83261 [m^3/s]
# Time =  447735.00 [min],  Q_out =   69.66315 [m^3/s]
# Time =  448440.00 [min],  Q_out =   76.53494 [m^3/s]
# Time =  449145.00 [min],  Q_out =   76.21937 [m^3/s]
# Time =  449843.33 [min],  Q_out =   73.66547 [m^3/s]
# Time =  450525.00 [min],  Q_out =   69.77607 [m^3/s]
# Time =  451200.00 [min],  Q_out =   63.72238 [m^3/s]
# Time =  451905.00 [min],  Q_out =   56.97085 [m^3/s]
# Time =  452595.00 [min],  Q_out =   52.34995 [m^3/s]
# Time =  453270.00 [min],  Q_out =   54.89618 [m^3/s]
# Time =  453945.00 [min],  Q_out =   68.64140 [m^3/s]
# Time =  454620.00 [min],  Q_out =  112.79178 [m^3/s]
# Time =  455310.00 [min],  Q_out =  113.35155 [m^3/s]
# Time =  456000.00 [min],  Q_out =   99.24280 [m^3/s]
# Time =  456675.00 [min],  Q_out =   86.52031 [m^3/s]
# Time =  457321.67 [min],  Q_out =   76.57157 [m^3/s]
# Time =  458010.00 [min],  Q_out =   67.51235 [m^3/s]
# Time =  458670.00 [min],  Q_out =   59.75878 [m^3/s]
# Time =  459360.00 [min],  Q_out =   52.59195 [m^3/s]
# Time =  460050.00 [min],  Q_out =   46.87635 [m^3/s]
# Time =  460751.67 [min],  Q_out =   42.68506 [m^3/s]
# Time =  461445.00 [min],  Q_out =   39.21867 [m^3/s]
# Time =  462153.33 [min],  Q_out =   36.09023 [m^3/s]
# Time =  462840.00 [min],  Q_out =   33.64793 [m^3/s]
# Time =  463545.00 [min],  Q_out =   31.97226 [m^3/s]
# Time =  464235.00 [min],  Q_out =   30.58226 [m^3/s]
# Time =  464910.00 [min],  Q_out =   28.68924 [m^3/s]
# Time =  465585.00 [min],  Q_out =   26.45363 [m^3/s]
# Time =  466275.00 [min],  Q_out =   24.64787 [m^3/s]
# Time =  466940.00 [min],  Q_out =   23.46613 [m^3/s]
# Time =  467596.67 [min],  Q_out =   22.15503 [m^3/s]
# Time =  468285.00 [min],  Q_out =   20.45913 [m^3/s]
# Time =  468925.00 [min],  Q_out =   18.79160 [m^3/s]
# Time =  469560.00 [min],  Q_out =   17.22181 [m^3/s]
# Time =  470235.00 [min],  Q_out =   15.71941 [m^3/s]
# Time =  470925.00 [min],  Q_out =   14.36242 [m^3/s]
# Time =  471600.00 [min],  Q_out =   13.18823 [m^3/s]
# Time =  472260.00 [min],  Q_out =   12.16851 [m^3/s]
# Time =  472935.00 [min],  Q_out =   11.24304 [m^3/s]
# Time =  473625.00 [min],  Q_out =   10.40657 [m^3/s]
# Time =  474300.00 [min],  Q_out =    9.99169 [m^3/s]
# Time =  474960.00 [min],  Q_out =   10.28659 [m^3/s]
# Time =  475656.67 [min],  Q_out =   11.77584 [m^3/s]
# Time =  476355.00 [min],  Q_out =   16.31895 [m^3/s]
# Time =  477060.00 [min],  Q_out =   24.16384 [m^3/s]
# Time =  477720.00 [min],  Q_out =   31.80595 [m^3/s]
# Time =  478410.00 [min],  Q_out =   34.56332 [m^3/s]
# Time =  479100.00 [min],  Q_out =   33.55414 [m^3/s]
# Time =  479790.00 [min],  Q_out =   33.16520 [m^3/s]
# Time =  480456.67 [min],  Q_out =   52.95674 [m^3/s]
# Time =  481080.00 [min],  Q_out =   78.92458 [m^3/s]
# Time =  481746.67 [min],  Q_out =   97.12810 [m^3/s]
# Time =  482415.00 [min],  Q_out =  100.35336 [m^3/s]
# Time =  483090.00 [min],  Q_out =   87.89181 [m^3/s]
# Time =  483765.00 [min],  Q_out =   73.07061 [m^3/s]
# Time =  484440.00 [min],  Q_out =   60.35746 [m^3/s]
# Time =  485130.00 [min],  Q_out =   50.45418 [m^3/s]
# Time =  485835.00 [min],  Q_out =   43.31709 [m^3/s]
# Time =  486555.00 [min],  Q_out =   38.50425 [m^3/s]
# Time =  487215.00 [min],  Q_out =   36.46614 [m^3/s]
# Time =  487890.00 [min],  Q_out =   38.36653 [m^3/s]
# Time =  488565.00 [min],  Q_out =   43.20925 [m^3/s]
# Time =  489240.00 [min],  Q_out =   46.39839 [m^3/s]
# Time =  489933.33 [min],  Q_out =   45.68471 [m^3/s]
# Time =  490621.67 [min],  Q_out =   41.65710 [m^3/s]
# Time =  491318.33 [min],  Q_out =   36.34430 [m^3/s]
# Time =  492000.00 [min],  Q_out =   31.32773 [m^3/s]
# Time =  492690.00 [min],  Q_out =   26.93332 [m^3/s]
# Time =  493380.00 [min],  Q_out =   23.29241 [m^3/s]
# Time =  494055.00 [min],  Q_out =   20.63830 [m^3/s]
# Time =  494730.00 [min],  Q_out =   22.78164 [m^3/s]
# Time =  495420.00 [min],  Q_out =   30.92091 [m^3/s]
# Time =  496080.00 [min],  Q_out =   32.65570 [m^3/s]
# Time =  496770.00 [min],  Q_out =   30.34151 [m^3/s]
# Time =  497435.00 [min],  Q_out =   28.27320 [m^3/s]
# Time =  498105.00 [min],  Q_out =   28.14615 [m^3/s]
# Time =  498765.00 [min],  Q_out =   30.71059 [m^3/s]
# Time =  499440.00 [min],  Q_out =   37.76742 [m^3/s]
# Time =  500145.00 [min],  Q_out =   47.79615 [m^3/s]
# Time =  500850.00 [min],  Q_out =   57.19589 [m^3/s]
# Time =  501541.67 [min],  Q_out =   66.88391 [m^3/s]
# Time =  502230.00 [min],  Q_out =   74.75861 [m^3/s]
# Time =  502920.00 [min],  Q_out =   72.39102 [m^3/s]
# Time =  503625.00 [min],  Q_out =   67.67692 [m^3/s]
# Time =  504300.00 [min],  Q_out =   64.40453 [m^3/s]
# Time =  504976.67 [min],  Q_out =   63.65951 [m^3/s]
# Time =  505680.00 [min],  Q_out =   66.04486 [m^3/s]
# Time =  506370.00 [min],  Q_out =   66.92600 [m^3/s]
# Time =  507075.00 [min],  Q_out =   64.43029 [m^3/s]
# Time =  507735.00 [min],  Q_out =   62.25401 [m^3/s]
# Time =  508440.00 [min],  Q_out =   58.70728 [m^3/s]
# Time =  509130.00 [min],  Q_out =   52.05531 [m^3/s]
# Time =  509790.00 [min],  Q_out =   45.54871 [m^3/s]
# Time =  510450.00 [min],  Q_out =   41.72076 [m^3/s]
# Time =  511125.00 [min],  Q_out =   38.92709 [m^3/s]
# Time =  511785.00 [min],  Q_out =   39.21010 [m^3/s]
# Time =  512445.00 [min],  Q_out =   39.57731 [m^3/s]
# Time =  513150.00 [min],  Q_out =   36.49298 [m^3/s]
# Time =  513810.00 [min],  Q_out =   33.66766 [m^3/s]
# Time =  514455.00 [min],  Q_out =   39.28679 [m^3/s]
# Time =  515160.00 [min],  Q_out =   56.23104 [m^3/s]
# Time =  515835.00 [min],  Q_out =   56.54471 [m^3/s]
# Time =  516540.00 [min],  Q_out =   50.23328 [m^3/s]
# Time =  517245.00 [min],  Q_out =   43.80664 [m^3/s]
# Time =  517950.00 [min],  Q_out =   39.20392 [m^3/s]
# Time =  518640.00 [min],  Q_out =   36.18018 [m^3/s]
# Time =  519325.00 [min],  Q_out =   33.55038 [m^3/s]
# Time =  519990.00 [min],  Q_out =   31.61083 [m^3/s]
# Time =  520680.00 [min],  Q_out =   30.53620 [m^3/s]
# Time =  521370.00 [min],  Q_out =   29.54947 [m^3/s]
# Time =  522060.00 [min],  Q_out =   27.98718 [m^3/s]
# Time =  522750.00 [min],  Q_out =   26.00805 [m^3/s]
# Time =  523440.00 [min],  Q_out =   23.94137 [m^3/s]
# Time =  524116.67 [min],  Q_out =   22.00932 [m^3/s]
# Time =  524790.00 [min],  Q_out =   20.28053 [m^3/s]
# Time =  525465.00 [min],  Q_out =   19.73613 [m^3/s]
# Stopping: Reached stop time = 525600.0.
#
# Meteorology component: Finished.
# Diversions component: Finished.
# Channels component: Finished.
# Snow component: Finished.
# Groundwater component: Finished.
# Evaporation component: Finished.
# Infiltration component: Finished.
# Ice component: Finished.
# =======================
# Simulation complete.
# =======================
#
# ------------------------------------------------------------
# TopoFlow Version 3.62 (2020-06-02)
# Tue Jul 27 15:28:52 2021
#
# Input directory:      /Users/peckhams/TF_Tests/Tana_120sec/
# Output directory:     /Users/peckhams/TF_Tests/Tana_120sec/
# Site prefix:          Tana_120sec
# Case prefix:          Test1
#
# Simulated time:      525600.0 [min]
# Program run time:    6.178285253047943 [min]
#
# Number of timesteps: 315360
# Number of columns:   131
# Number of rows:      115
#
# T_stop:            525600.0 [min]
#
# Main outlet ID:    (95, 119) (row, col)
# Basin_area:        94284.4 [km^2]
#
# Min Manning's n:   0.030000001192092896
# Max Manning's n:   1.0
#
# Q_final:           20.039154317613534 [m^3/s]
# Q_peak:            351.7627651738179 [m^3/s]
# Q_peak_time:       115350.0 [min]
# u_peak:            1.2375191340824954 [m/s]
# u_peak_time:       115335.0 [min]
# d_peak:            2.32531372923753 [m]
# d_peak_time:       115335.0 [min]
#
# Max(precip rate):  7.039565116429003 [mm/hr]
#
# Total accumulated volumes over entire DEM: (fluxes)
# vol_P    (precip):        23908.669520443855 x 10^6 [m^3]   (incl. leq snowfall)
# vol_Q    (discharge):     2951.4073659513106 x 10^6 [m^3]   (main basin outlet)
# vol_SM   (snowmelt):      0.0 [m^3]
# vol_MR   (icemelt):       0.0 [m^3]
# vol_ET   (evaporation):   0.0 [m^3]
# vol_IN   (infiltration):  0.0 [m^3]
# vol_Rg   (recharge):      0.0 [m^3]   (bottom loss)
# vol_GW   (baseflow):      0.0 [m^3]
# vol_R    (runoff):        23908.669520443036 x 10^6 [m^3]  R = (P+SM+MR) - (ET+IN)
#
# Total accumulated volumes over entire DEM: (storage)
# vol_soil  (infiltration):  0.0 [m^3]  (change in storage)
# vol_chan0 (channels):      72.84777914048261 x 10^6 [m^3]  (initial)
# vol_chan  (channels):      68.9666795138187 x 10^6 [m^3]
# vol_land  (surface):       206.66137681520647 x 10^6 [m^3]
# vol_edge  (boundary):      23705.889243255322 x 10^6 [m^3]
# vol_swe   (snowpack):      0.0 [m^3]
#
# Mass balance check:
# volume in         = 23908.669520443855 x 10^6 [m^3]
# volume out        = 23705.889243255322 x 10^6 [m^3]
# change in storage = 202.78027718854256 x 10^6 [m^3]
# volume gain error = 7.62939453125e-06 [m^3]
# vol_error/ vol_in = 3.1910577561525317e-16
#
# Final grid mins and maxes:
# Min(Q), Max(Q):   0.0000, 67.8021 [m^3/s]
# Min(u), Max(u):   0.0000, 1.9592 [m/s]
# Min(d), Max(d):   0.0000, 3.1597 [m]
#
# Finished.  (Test1)

# %% [markdown]
# ## Show a Grid from a Grid Stack in an RTS File  <a id="show_grid"></a>

# %%
long_name = 'River Discharge'
rts_filename = output_dir + cfg_prefix + '_2D-Q.rts'
rts = rts_files.rts_file()
OK  = rts.open_file( rts_filename )
if not(OK):
    print('Sorry, Could not open RTS file:')
    print( rts_filename )

n_grids = int( rts.number_of_grids() )
# time_index = 2
# time_index = int(n_grids / 2)
time_index = int(n_grids - 1)
byte_swap  = rts.byte_swap_needed()
grid   = rts.read_grid( time_index )   # alias to get_grid()
extent = rts.get_bounds()
rts.close_file()

print('Byte swap needed =', byte_swap )
print('Number of grids in RTS file  =', n_grids)
print('Reading one grid from RTS file... ')
print('  time_index =', time_index )
print('extent =', extent)
print('min(grid), max(grid) =', grid.min(), grid.max())
print('Finished.')
print()

tfvis.show_grid_as_image( grid, long_name, extent=extent,
                          BLACK_ZERO=True,
                          cmap='rainbow', stretch='power', p=0.3,
                          # a=1, b=2, p=0.5,
                          xsize=7, ysize=7, dpi=None)
# Out:
# Byte swap needed = False
# Number of grids in RTS file  = 4380
# Reading one grid from RTS file...
#   time_index = 4379
# extent = [36.4, 40.766666666667, -3.143333333333, 0.69]
# min(grid), max(grid) = 0.0 68.71625
# Finished.

# %% [markdown]
# ## Plot a Time Series for Outlet Values  <a id="plot_data"></a>

# %%
os.chdir(output_dir)
var_index = 3
nc_file = cfg_prefix + '_0D-Q.nc'
# nc_file = cfg_prefix + '_0D-d-flood.nc'

tfvis.plot_time_series(nc_file, output_dir=output_dir, var_index=var_index,
                       marker=',', REPORT=True, xsize=8, ysize=5)

# Save the image to a file instead
# im_file = cfg_prefix + '_0D-Q.png'
# # im_file = cfg_prefix + '_0D-d-flood.png'
# tfvis.plot_time_series(nc_file, output_dir=output_dir, var_index=var_index,
#                           marker=',', REPORT=True, xsize=10, ysize=4,
#                           im_file=im_file)
# Out:
# var_names in netCDF file =
# ['time', 'datetime', 'Q_95_119', 'Q_94_118']
# var longitudes =
# [40.38333333333333, 40.35]
# var latitudes =
# [-2.493333333333, -2.459999999999667]

# %%
from topoflow.utils import ncts_files
ncts = ncts_files.ncts_file()

# output_dir = '/Users/peckhams/TF_Tests/Tana_120sec/'
nc_file = output_dir + 'Test1' + '_0D-Q.nc'
# nc_file = cfg_prefix + '_0D-Q.nc'
ncts.open_file( nc_file )
var_name_list = ncts.get_var_names()
var_index = 2
var_name = var_name_list[ var_index ]
ts_values = ncts.get_values( var_name )
ts_times  = ncts.get_times()
ts_datetimes = ncts.get_datetimes()

values    = ts_values[:]
times     = ts_times[:]
datetimes = ts_datetimes[:]
print('n_values    =', values.size)
print('n_times     =', times.size)
print('Qmin, Qmax  =', values.min(), values.max())
print('tmin, tmax  =', times.min(), times.max())
print('times.dtype =', times.dtype)
print()
print('times[-10:-1] =')
print(times[-10:-1])
# print(times[-94])
print('datetimes[0:10] =')
print(datetimes[0:10])
# Out:
# n_values    = 35040
# n_times     = 35040
# Qmin, Qmax  = 0.0 874.4555
# tmin, tmax  = 0.0 525585.0
# times.dtype = float64
#
# times[-10:-1] =
# [525450. 525465. 525480. 525495. 525510. 525525. 525540. 525555. 525570.]
# datetimes[0:10] =
# ['2015-10-01 00:00:00' '2015-10-01 00:15:00' '2015-10-01 00:30:00'
#  '2015-10-01 00:45:00' '2015-10-01 01:00:00' '2015-10-01 01:15:00'
#  '2015-10-01 01:30:00' '2015-10-01 01:45:00' '2015-10-01 02:00:00'
#  '2015-10-01 02:15:00']

# %% [markdown]
# ## Test2:  CHIRPS Rainfall, with Richards 1D Infiltration <a id="Test2"></a>

# %% [markdown]
# In this test, we use everything exactly as in Test1, except we Enable the Richard 1D Infiltration component. So now only 3 process components are enabled, namely:  <b>Meteorology</b>, <b>Channels - Kinematic Wave</b> and <b>Infiltration - Richards 1D</b>.  All other processes (evaporation, snowmelt, icemelt, diversions) have <b>comp_status</b> set to Disabled in their CFG files.  The case prefix for this scenario is <b>Test2</b>.
#
# <b>Note:</b>  There is a problem when we set slope_file to
# site_prefix_new-slope.rtg, instead of site_prefix_slope.rtg in the channel process CFG file.

# %%
cfg_prefix = 'Test2'
cfg_dir    = home_dir + '/TF_Tests/Tana_120sec/Test2_cfg/'
output_dir = home_dir + '/TF_Tests/Tana_120sec/Test2_Output'

main.run_model(cfg_prefix=cfg_prefix, cfg_directory=cfg_dir)
# Out:
# EMELI: Reading info from provider_file:
#     /Users/peckhams/TF_Tests/Tana_120sec/Test2_cfg/Test2_providers.txt
# EMELI: Reading info from comp_repo_file:
#     /Users/peckhams/Dropbox/TopoFlow_3.6/topoflow/framework/component_repository.xml
#
# EMELI: Instantiated component: tf_meteorology
# EMELI: Instantiated component: tf_diversions_fraction_method
# EMELI: Instantiated component: tf_channels_kin_wave
# EMELI: Instantiated component: tf_snow_degree_day
# EMELI: Instantiated component: tf_satzone_darcy_layers
# EMELI: Instantiated component: tf_evap_priestley_taylor
# EMELI: Instantiated component: tf_infil_richards_1d
# EMELI: Instantiated component: tf_ice_gc2d
# EMELI: Instantiated component: topoflow_driver
# Driver component name = topoflow_driver
#
# Meteorology component: Initializing...
# Reading config file into component state.
# In met_base read_input_files():
#    time = 0.0
#    min(P) = 0.0 [mmph]
#    max(P) = 0.0052423921204081125 [mmph]
#
# ------------------------------------------
#  NOTE: Since PRECIP_ONLY = True, output
#        variables for met component will
#        not be computed or saved to files.
#        And evap component may not work.
# ------------------------------------------
#
# EMELI: Initialized component: tf_meteorology.
#
# Diversions component: Initializing...
# Reading config file into component state.
# Diversions component: Disabled in CFG file.
# EMELI: Initialized component: tf_diversions_fraction_method.
#
# Channels component: Initializing...
# Reading config file into component state.
# CHANNELS calling initialize_d8_vars()...
# D8 component: Initializing...
# Reading config file into component state.
# Reading grid values...
# Finished reading grid from:
#   /Users/peckhams/TF_Tests/Tana_120sec/__topo/Tana_120sec_DEM.rtg
#    min(DEM), max(DEM) = 0.0 5269.4604
#
# Filling pits in initial DEM...
# Number of nodata and NaN values = 0
# Finished initializing "closed" array.
#
# Putting boundary pixels on heap...
# Number of pixels on heap = 488
# Finished with heap insertion.
#
# n_closed = 0 of 15065
# n_closed = 5000 of 15065
# n_closed = 10000 of 15065
# n_closed = 15000 of 15065
# Total pixels   = 15065
# Raised  pixels = 0
# Drained pixels = 15067
# Run time for fill_pits() =     0.2345 [seconds]
# Finished with fill_pits().
#
# Imported netCDF4 version: 1.5.7
# D8 component: Updating...
# Updating D8 flow grid...
#    update_d8_codes(): Initializing grid...
#    --------------------------------------------
#    Data type of flow grid at start = int16
#    Number of flats         = 482
#    Number of 1-pixel pits  = 13
#    Number of nodata/NaN    = 346
#    min(codes), max(codes)  = -255, 136
#    --------------------------------------------
#    update_d8_codes(): Breaking ties...
#    update_d8_codes(): Linking flats...
#    Number of iterations = 13 (in link_flats())
# Updating flow width grid...
#     min(dw), max(dw) = 3685.809, 5230.1157 [m]
# Updating flow length grid...
#     min(ds), max(ds) = 3685.809, 5230.1157 [m]
# Updating upstream area grid...
#     min(A), max(A) = 0.0, 94284.44 [km^2]
#     Number of iterations = 175
# Saving D8 grids specified in CFG file...
# CHANNELS calling read_input_files()...
# CHANNELS calling set_computed_input_vars()...
# CHANNELS calling initialize_computed_vars()...
#     min(nval)       = 0.030000001192092896
#     max(nval)       = 1.0
#     min(width)      = 1.0
#     max(width)      = 120.0
#     min(angle)      = 29.999999999999996 [deg]
#     max(angle)      = 29.999999999999996 [deg]
#     min(sinuosity)  = 1.0
#     max(sinuosity)  = 1.0
#     min(init_depth) = 0.0006527226651087403
#     max(init_depth) = 2.5116665363311768
# Initializing u, f, d grids...
# Total number of slope values = 15065
# Number of zero values        = 730 (maybe edge)
# Number of negative values    = 0
# Number of NaN values         = 0
# Number of infinite values    = 0
# -------------------------------------------------
# WARNING: Zero, negative or NaN slopes found.
#          Replacing them with smallest slope.
#          Consider using "new_slopes.py" instead.
#          min(S) = 3.21667903335765e-06
#          max(S) = 0.5583505630493164
# -------------------------------------------------
#
# Imported netCDF4 version: 1.5.7
# EMELI: Initialized component: tf_channels_kin_wave.
#
# Snow component: Initializing...
# Reading config file into component state.
# Snow component: Disabled in CFG file.
# EMELI: Initialized component: tf_snow_degree_day.
#
# Groundwater component: Initializing...
# Reading config file into component state.
# Groundwater component: Disabled in CFG file.
# EMELI: Initialized component: tf_satzone_darcy_layers.
#
# Evaporation component: Initializing...
# Reading config file into component state.
# Evaporation component: Disabled in CFG file.
# EMELI: Initialized component: tf_evap_priestley_taylor.
#
# Infiltration component: Initializing...
# Reading config file into component state.
# INFIL calling read_input_files()...
# INFIL calling set_computed_input_vars()...
# INFIL calling initialize_computed_vars()...
# Imported netCDF4 version: 1.5.7
# EMELI: Initialized component: tf_infil_richards_1d.
#
# Ice component: Initializing...
# Reading config file into component state.
# Ice component: Disabled in CFG file.
# EMELI: Initialized component: tf_ice_gc2d.
#
# TopoFlow component: Initializing...
# Reading config file into component state.
# Setting stop method to: Until_model_time
# Opening log file:
#     log_file = /Users/peckhams/TF_Tests/Tana_120sec/Test2.log
# Starting TopoFlow model run...
# EMELI: Initialized component: topoflow_driver.
#
# EMELI: Component time step sizes =
#     tf_meteorology = 21600.0 [seconds]
#     tf_diversions_fraction_method is Disabled.
#     tf_channels_kin_wave = 900.0 [seconds]
#     tf_snow_degree_day is Disabled.
#     tf_satzone_darcy_layers is Disabled.
#     tf_evap_priestley_taylor is Disabled.
#     tf_infil_richards_1d = 5.0 [seconds]
#     tf_ice_gc2d is Disabled.
#     topoflow_driver = 100.0 [seconds]
# Converting all time step units to seconds...
# Component with smallest time step is: tf_infil_richards_1d
#
# Time interpolation method = Linear
#
# Will print values every 0.5 seconds.
# Time =       1.67 [min],  Q_out =    0.00000 [m^3/s]
# Time =       3.33 [min],  Q_out =    0.00000 [m^3/s]
# Time =       5.00 [min],  Q_out =    0.00000 [m^3/s]
