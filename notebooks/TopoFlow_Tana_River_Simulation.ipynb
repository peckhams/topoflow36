# %% [markdown]
# # Running TopoFlow for the Tana River, Kenya

# %% [markdown]
# #### Table of Contents

# %% [markdown]
# 1.  <a href="#Import">Import Required Packages</a> <br>
# 2.  <a href="#Intro">Introduction</a> <br>
# 3.  <a href="#Test1">CHIRPS 6-hr Rainfall, with No Infiltration</a> <br>
# 4.  <a href="#show_grid">Show One Grid from the RTS File</a> <br>
# 5.  <a href="#plot_data">Plot a Time Series for Outlet Values</a> <br>
# 6.  <a href="#Test2">CHIRPS 6-hr Rainfall, with Richards 1D Infiltration</a> <br>

# %% [markdown]
# ## Import Required Packages <a id="Import"></a>

# %%
from topoflow import main
from topoflow.framework import emeli
examples_dir = emeli.paths['examples']
import os, os.path
from topoflow.utils import visualize as tfvis
from topoflow.utils import rts_files

# from topoflow.utils import rtg_files

home_dir   = os.path.expanduser("~")
cfg_prefix = 'Test1'
cfg_dir    = home_dir + '/TF_Tests/Tana_120sec/Test1_cfg/'
output_dir = home_dir + '/TF_Tests/Tana_120sec/'

print('Examples directory  =', examples_dir)
print('Your Home directory =', home_dir)
print('CFG directory       =', cfg_dir)
print('Output directory    =', output_dir)
# Out:
# Importing TopoFlow 3.6 package modules:
#    topoflow.utils
#    topoflow.utils.tests
#    topoflow.components
#    topoflow.components.tests
#    topoflow.framework
#    topoflow.framework.tests
#
# Examples directory  = /Users/peckhams/Dropbox/TopoFlow_3.6/topoflow/examples/
# Your Home directory = /Users/peckhams
# CFG directory       = /Users/peckhams/TF_Tests/Tana_120sec/Test1_cfg/
# Output directory    = /Users/peckhams/TF_Tests/Tana_120sec/

# %% [markdown]
# ## Introduction <a id="Intro"></a>

# %% [markdown]
# This notebook assumes that you are already familiar with the basic concepts of TopoFlow and how to run it.  The Jupyter notebook called <b>TopoFlow_Getting_Started.ipynb</b> provides that information.
#
# This notebook also assumes that you have already created all of the input files needed to run TopoFlow for the Tana River basin.  The Jupyter notebook called <b>TopoFlow_Prepare_Input_Data.ipynb</b> can be used for that purpose.

# %% [markdown]
# ## Test1:  CHIRPS Rainfall & Runoff, with No Infiltration  <a id="Test1"></a>

# %% [markdown]
# In this test, we use space-time rainfall from the CHIRPS rainfall product, as specified in the CFG file for the Meteorology component.  (Note that the timestep, dt in Test1_meteorology.cfg should be set to: 21600 seconds, or 6 hours.) For the channel flow process, we use the Kinematic Wave method.  So only 2 process components are enabled, namely:  <b>Meteorology</b> and <b>Channels - Kinematic Wave</b>.  All other processes (infiltration, evaporation, snowmelt, icemelt, diversions) have <b>comp_status</b> set to Disabled in their CFG files.  The case prefix for this scenario is <b>Test1</b>.

# %%
main.run_model(cfg_prefix=cfg_prefix, cfg_directory=cfg_dir)
# Out:
# EMELI: Reading info from provider_file:
#     /Users/peckhams/TF_Tests/Tana_120sec/Test1_cfg/Test1_providers.txt
# EMELI: Reading info from comp_repo_file:
#     /Users/peckhams/Dropbox/TopoFlow_3.6/topoflow/framework/component_repository.xml
#
# EMELI: Instantiated component: tf_meteorology
# EMELI: Instantiated component: tf_diversions_fraction_method
# EMELI: Instantiated component: tf_channels_kin_wave
# EMELI: Instantiated component: tf_snow_degree_day
# EMELI: Instantiated component: tf_satzone_attenuate
# EMELI: Instantiated component: tf_evap_priestley_taylor
# EMELI: Instantiated component: tf_infil_richards_1d
# EMELI: Instantiated component: tf_ice_gc2d
# EMELI: Instantiated component: topoflow_driver
# Driver component name = topoflow_driver
#
# Meteorology component: Initializing...
# Reading config file into component state.
# In met_base read_input_files():
#    time = 0.0
#    min(P) = 0.0 [mmph]
#    max(P) = 0.0052423921204081125 [mmph]
#
# ------------------------------------------
#  NOTE: Since PRECIP_ONLY = True, output
#        variables for met component will
#        not be computed or saved to files.
#        And evap component may not work.
# ------------------------------------------
#
# EMELI: Initialized component: tf_meteorology.
#
# Diversions component: Initializing...
# Reading config file into component state.
# Diversions component: Disabled in CFG file.
# EMELI: Initialized component: tf_diversions_fraction_method.
#
# Channels component: Initializing...
# Reading config file into component state.
# CHANNELS calling initialize_d8_vars()...
# D8 component: Initializing...
# Reading config file into component state.
# Reading grid values...
# Finished reading grid from:
#   /Users/peckhams/TF_Tests/Tana_120sec/__topo/Tana_120sec_DEM.rtg
#    min(DEM), max(DEM) = 0.0 5269.4604
#
# Filling pits in initial DEM...
# Number of nodata and NaN values = 0
# Finished initializing "closed" array.
#
# Putting boundary pixels on heap...
# Number of pixels on heap = 488
# Finished with heap insertion.
#
# n_closed = 0 of 15065
# n_closed = 5000 of 15065
# n_closed = 10000 of 15065
# n_closed = 15000 of 15065
# Total pixels   = 15065
# Raised  pixels = 0
# Drained pixels = 15067
# Run time for fill_pits() =     0.2346 [seconds]
# Finished with fill_pits().
#
# Imported netCDF4 version: 1.5.7
# D8 component: Updating...
# Updating D8 flow grid...
#    update_d8_codes(): Initializing grid...
#    --------------------------------------------
#    Data type of flow grid at start = int16
#    Number of flats         = 482
#    Number of 1-pixel pits  = 13
#    Number of nodata/NaN    = 346
#    min(codes), max(codes)  = -255, 136
#    --------------------------------------------
#    update_d8_codes(): Breaking ties...
#    update_d8_codes(): Linking flats...
#    Number of iterations = 13 (in link_flats())
# Updating flow width grid...
#     min(dw), max(dw) = 3685.809, 5230.1157 [m]
# Updating flow length grid...
#     min(ds), max(ds) = 3685.809, 5230.1157 [m]
# Updating upstream area grid...
#     min(A), max(A) = 0.0, 94284.44 [km^2]
#     Number of iterations = 175
# Saving D8 grids specified in CFG file...
# CHANNELS calling read_input_files()...
# CHANNELS calling set_computed_input_vars()...
# --------------------------------------------------
# NOTE:  save_pixels_dt read from CFG file is less
#        than the channel component timestep, dt.
#        Will write values at interval dt instead.
# --------------------------------------------------
#
# CHANNELS calling initialize_computed_vars()...
#     min(nval)       = 0.030000001192092896
#     max(nval)       = 1.0
#     min(width)      = 1.0
#     max(width)      = 120.0
#     min(angle)      = 29.999999999999996 [deg]
#     max(angle)      = 29.999999999999996 [deg]
#     min(sinuosity)  = 1.0
#     max(sinuosity)  = 1.0
#     min(init_depth) = 0.0006527226651087403
#     max(init_depth) = 2.5116665363311768
# Initializing u, f, d grids...
# Total number of slope values = 15065
# Number of zero values        = 730 (maybe edge)
# Number of negative values    = 0
# Number of NaN values         = 0
# Number of infinite values    = 0
# -------------------------------------------------
# WARNING: Zero, negative or NaN slopes found.
#          Replacing them with smallest slope.
#          Consider using "new_slopes.py" instead.
#          min(S) = 3.21667903335765e-06
#          max(S) = 0.5583505630493164
# -------------------------------------------------
#
# Imported netCDF4 version: 1.5.7
# EMELI: Initialized component: tf_channels_kin_wave.
#
# Snow component: Initializing...
# Reading config file into component state.
# Snow component: Disabled in CFG file.
# EMELI: Initialized component: tf_snow_degree_day.
#
# Groundwater component: Initializing...
# Reading config file into component state.
# D8 component: Initializing...
# Reading config file into component state.
# Reading grid values...
# Finished reading grid from:
#   /Users/peckhams/TF_Tests/Tana_120sec/__topo/Tana_120sec_DEM.rtg
#    min(DEM), max(DEM) = 0.0 5269.4604
#
# Filling pits in initial DEM...
# Number of nodata and NaN values = 0
# Finished initializing "closed" array.
#
# Putting boundary pixels on heap...
# Number of pixels on heap = 488
# Finished with heap insertion.
#
# n_closed = 0 of 15065
# n_closed = 5000 of 15065
# n_closed = 10000 of 15065
# n_closed = 15000 of 15065
# Total pixels   = 15065
# Raised  pixels = 0
# Drained pixels = 15067
# Run time for fill_pits() =     0.2458 [seconds]
# Finished with fill_pits().
#
# Imported netCDF4 version: 1.5.7
# D8 component: Updating...
# Updating D8 flow grid...
#    update_d8_codes(): Initializing grid...
#    --------------------------------------------
#    Data type of flow grid at start = int16
#    Number of flats         = 482
#    Number of 1-pixel pits  = 13
#    Number of nodata/NaN    = 346
#    min(codes), max(codes)  = -255, 136
#    --------------------------------------------
#    update_d8_codes(): Breaking ties...
#    update_d8_codes(): Linking flats...
#    Number of iterations = 13 (in link_flats())
# Updating flow width grid...
#     min(dw), max(dw) = 3685.809, 5230.1157 [m]
# Updating flow length grid...
#     min(ds), max(ds) = 3685.809, 5230.1157 [m]
# Updating upstream area grid...
#     min(A), max(A) = 0.0, 94284.44 [km^2]
#     Number of iterations = 175
# Saving D8 grids specified in CFG file...
# Imported netCDF4 version: 1.5.7
# EMELI: Initialized component: tf_satzone_attenuate.
#
# Evaporation component: Initializing...
# Reading config file into component state.
# Evaporation component: Disabled in CFG file.
# EMELI: Initialized component: tf_evap_priestley_taylor.
#
# Infiltration component: Initializing...
# Reading config file into component state.
# Infiltration component: Disabled in CFG file.
# EMELI: Initialized component: tf_infil_richards_1d.
#
# Ice component: Initializing...
# Reading config file into component state.
# Ice component: Disabled in CFG file.
# EMELI: Initialized component: tf_ice_gc2d.
#
# TopoFlow component: Initializing...
# Reading config file into component state.
# Setting stop method to: Until_model_time
# Opening log file:
#     log_file = /Users/peckhams/TF_Tests/Tana_120sec/Test1.log
# Starting TopoFlow model run...
# EMELI: Initialized component: topoflow_driver.
#
# EMELI: Component time step sizes =
#     tf_meteorology = 21600.0 [seconds]
#     tf_diversions_fraction_method is Disabled.
#     tf_channels_kin_wave = 900.0 [seconds]
#     tf_snow_degree_day is Disabled.
#     tf_satzone_attenuate = 3600.0 [seconds]
#     tf_evap_priestley_taylor is Disabled.
#     tf_infil_richards_1d is Disabled.
#     tf_ice_gc2d is Disabled.
#     topoflow_driver = 100.0 [seconds]
# Converting all time step units to seconds...
# Component with smallest time step is: topoflow_driver
#
# Time interpolation method = Linear
#
# Baseflow at: 7784 grid cells.
# Will print values every 0.5 seconds.
# Baseflow at: 7750 grid cells.
# Baseflow at: 7559 grid cells.
# Baseflow at: 7558 grid cells.
# Baseflow at: 7558 grid cells.
# Baseflow at: 7560 grid cells.
# Baseflow at: 7566 grid cells.
# Baseflow at: 7565 grid cells.
# Baseflow at: 7566 grid cells.
# Time =     480.00 [min],  Q_out =  364.57899 [m^3/s]
# Baseflow at: 7566 grid cells.
# Baseflow at: 7566 grid cells.
# Baseflow at: 7566 grid cells.
# Baseflow at: 7564 grid cells.
# Baseflow at: 7564 grid cells.
# Baseflow at: 7564 grid cells.
# Baseflow at: 7564 grid cells.
# Baseflow at: 7565 grid cells.
# Baseflow at: 7565 grid cells.
# Time =    1065.00 [min],  Q_out =  372.93611 [m^3/s]
# Baseflow at: 7657 grid cells.
# Baseflow at: 7657 grid cells.
# Baseflow at: 7657 grid cells.
# Baseflow at: 7657 grid cells.
# Baseflow at: 7657 grid cells.
# Baseflow at: 7657 grid cells.
# Baseflow at: 7851 grid cells.
# Baseflow at: 7850 grid cells.
# Baseflow at: 7850 grid cells.
# Baseflow at: 7850 grid cells.
# Baseflow at: 7850 grid cells.
# Time =    1695.00 [min],  Q_out =  379.48904 [m^3/s]
# Baseflow at: 7850 grid cells.
# Baseflow at: 7689 grid cells.
# Baseflow at: 7689 grid cells.
# Baseflow at: 7689 grid cells.
# Baseflow at: 7689 grid cells.
# Baseflow at: 7689 grid cells.
# Baseflow at: 7689 grid cells.
# Baseflow at: 7628 grid cells.
# Baseflow at: 7628 grid cells.
# Baseflow at: 7628 grid cells.
# Time =    2320.00 [min],  Q_out =  368.07655 [m^3/s]
# Baseflow at: 7628 grid cells.
# Baseflow at: 7628 grid cells.
# Baseflow at: 7628 grid cells.
# Baseflow at: 7826 grid cells.
# Baseflow at: 7822 grid cells.
# Baseflow at: 7822 grid cells.
# Baseflow at: 7822 grid cells.
# Baseflow at: 7822 grid cells.
# Baseflow at: 7822 grid cells.
# Time =    2865.00 [min],  Q_out =  359.13730 [m^3/s]
# Baseflow at: 9007 grid cells.
# Baseflow at: 9011 grid cells.
# Baseflow at: 9008 grid cells.
# Baseflow at: 9008 grid cells.
# Baseflow at: 9008 grid cells.
# Baseflow at: 9008 grid cells.
# Baseflow at: 8718 grid cells.
# Baseflow at: 8718 grid cells.
# Baseflow at: 8718 grid cells.
# Baseflow at: 8718 grid cells.
# Time =    3465.00 [min],  Q_out =  351.99066 [m^3/s]
# Baseflow at: 8718 grid cells.
# Baseflow at: 8718 grid cells.
# Baseflow at: 8194 grid cells.
# Baseflow at: 8194 grid cells.
# Baseflow at: 8194 grid cells.
# Baseflow at: 8194 grid cells.
# Baseflow at: 8194 grid cells.
# Baseflow at: 8194 grid cells.
# Baseflow at: 8797 grid cells.
# Baseflow at: 8797 grid cells.
# Baseflow at: 8797 grid cells.
# Time =    4080.00 [min],  Q_out =  346.69560 [m^3/s]
# Baseflow at: 8797 grid cells.
# Baseflow at: 8797 grid cells.
# Baseflow at: 8797 grid cells.
# Baseflow at: 9440 grid cells.
# Baseflow at: 9437 grid cells.
# Baseflow at: 9437 grid cells.
# Baseflow at: 9436 grid cells.
# Baseflow at: 9436 grid cells.
# Baseflow at: 9436 grid cells.
# Baseflow at: 9320 grid cells.
# Time =    4695.00 [min],  Q_out =  342.29265 [m^3/s]
# Baseflow at: 9322 grid cells.
# Baseflow at: 9321 grid cells.
# Baseflow at: 9321 grid cells.
# Baseflow at: 9321 grid cells.
# Baseflow at: 9321 grid cells.
# Baseflow at: 8866 grid cells.
# Baseflow at: 8866 grid cells.
# Baseflow at: 8866 grid cells.
# Baseflow at: 8866 grid cells.
# Baseflow at: 8866 grid cells.
# Baseflow at: 8866 grid cells.
# Time =    5340.00 [min],  Q_out =  319.08592 [m^3/s]
# Baseflow at: 8652 grid cells.
# Baseflow at: 8652 grid cells.
# Baseflow at: 8652 grid cells.
# Baseflow at: 8651 grid cells.
# Baseflow at: 8651 grid cells.
# Baseflow at: 8651 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Time =    5940.00 [min],  Q_out =  280.09107 [m^3/s]
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Time =    6570.00 [min],  Q_out =  271.80524 [m^3/s]
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Time =    7200.00 [min],  Q_out =  284.05786 [m^3/s]
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Time =    7800.00 [min],  Q_out =  300.86631 [m^3/s]
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Time =    8415.00 [min],  Q_out =  367.68176 [m^3/s]
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 7621 grid cells.
# Baseflow at: 8735 grid cells.
# Baseflow at: 8732 grid cells.
# Baseflow at: 8732 grid cells.
# Baseflow at: 8732 grid cells.
# Baseflow at: 8732 grid cells.
# Baseflow at: 8732 grid cells.
# Baseflow at: 9189 grid cells.
# Baseflow at: 9188 grid cells.
# Time =    9075.00 [min],  Q_out =  443.30898 [m^3/s]
# Baseflow at: 9188 grid cells.
# Baseflow at: 9188 grid cells.
# Baseflow at: 9188 grid cells.
# Baseflow at: 9188 grid cells.
# Baseflow at: 8497 grid cells.
# Baseflow at: 8497 grid cells.
# Baseflow at: 8497 grid cells.
# Baseflow at: 8497 grid cells.
# Baseflow at: 8497 grid cells.
# Time =    9645.00 [min],  Q_out =  511.26675 [m^3/s]
# Baseflow at: 8497 grid cells.
# Baseflow at: 8577 grid cells.
# Baseflow at: 8578 grid cells.
# Baseflow at: 8578 grid cells.
# Baseflow at: 8578 grid cells.
# Baseflow at: 8578 grid cells.
# Baseflow at: 8578 grid cells.
# Baseflow at: 9160 grid cells.
# Baseflow at: 9161 grid cells.
# Baseflow at: 9158 grid cells.
# Baseflow at: 9158 grid cells.
# Time =   10290.00 [min],  Q_out =  522.99593 [m^3/s]
# Baseflow at: 9158 grid cells.
# Baseflow at: 9158 grid cells.
# Baseflow at: 9296 grid cells.
# Baseflow at: 9295 grid cells.
# Baseflow at: 9296 grid cells.
# Baseflow at: 9296 grid cells.
# Baseflow at: 9296 grid cells.
# Baseflow at: 9296 grid cells.
# Baseflow at: 8312 grid cells.
# Baseflow at: 8312 grid cells.
# Baseflow at: 8312 grid cells.
# Time =   10920.00 [min],  Q_out =  437.49087 [m^3/s]
# Baseflow at: 8312 grid cells.
# Baseflow at: 8312 grid cells.
# Baseflow at: 8312 grid cells.
# Baseflow at: 8518 grid cells.
# Baseflow at: 8518 grid cells.
# Baseflow at: 8518 grid cells.
# Baseflow at: 8518 grid cells.
# Baseflow at: 8518 grid cells.
# Baseflow at: 8518 grid cells.
# Baseflow at: 8382 grid cells.
# Time =   11550.00 [min],  Q_out =  396.65790 [m^3/s]
# Baseflow at: 8382 grid cells.
# Baseflow at: 8382 grid cells.
# Baseflow at: 8382 grid cells.
# Baseflow at: 8382 grid cells.
# Baseflow at: 8382 grid cells.
# Baseflow at: 8250 grid cells.
# Baseflow at: 8250 grid cells.
# Baseflow at: 8250 grid cells.
# Baseflow at: 8250 grid cells.
# Baseflow at: 8250 grid cells.
# Time =   12165.00 [min],  Q_out =  458.13881 [m^3/s]
# Baseflow at: 8250 grid cells.
# Baseflow at: 7861 grid cells.
# Baseflow at: 7861 grid cells.
# Baseflow at: 7861 grid cells.
# Baseflow at: 7861 grid cells.
# Baseflow at: 7861 grid cells.
# Baseflow at: 7861 grid cells.
# Baseflow at: 8282 grid cells.
# Baseflow at: 8282 grid cells.
# Baseflow at: 8282 grid cells.
# Baseflow at: 8282 grid cells.
# Time =   12810.00 [min],  Q_out =  445.69361 [m^3/s]
# Baseflow at: 8282 grid cells.
# Baseflow at: 8282 grid cells.
# Baseflow at: 7706 grid cells.
# Baseflow at: 7706 grid cells.
# Baseflow at: 7706 grid cells.
# Baseflow at: 7706 grid cells.
# Baseflow at: 7706 grid cells.
# Baseflow at: 7706 grid cells.
# Baseflow at: 7711 grid cells.
# Baseflow at: 7711 grid cells.
# Baseflow at: 7711 grid cells.
# Time =   13470.00 [min],  Q_out =  369.53120 [m^3/s]
# Baseflow at: 7711 grid cells.
# Baseflow at: 7711 grid cells.
# Baseflow at: 7711 grid cells.
# Baseflow at: 7691 grid cells.
# Baseflow at: 7691 grid cells.
# Baseflow at: 7691 grid cells.
# Baseflow at: 7691 grid cells.
# Baseflow at: 7691 grid cells.
# Baseflow at: 7691 grid cells.
# Baseflow at: 7691 grid cells.
# Baseflow at: 7691 grid cells.
# Time =   14118.33 [min],  Q_out =  309.57312 [m^3/s]
# Baseflow at: 7691 grid cells.
# Baseflow at: 7691 grid cells.
# Baseflow at: 7692 grid cells.
# Baseflow at: 7692 grid cells.
# Baseflow at: 7695 grid cells.
# Baseflow at: 7695 grid cells.
# Baseflow at: 7695 grid cells.
# Baseflow at: 7695 grid cells.
# Baseflow at: 7695 grid cells.
# Baseflow at: 7695 grid cells.
# Time =   14745.00 [min],  Q_out =  267.43775 [m^3/s]
# Baseflow at: 7741 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7674 grid cells.
# Baseflow at: 7674 grid cells.
# Baseflow at: 7674 grid cells.
# Baseflow at: 7674 grid cells.
# Baseflow at: 7674 grid cells.
# Time =   15390.00 [min],  Q_out =  226.93261 [m^3/s]
# Baseflow at: 7674 grid cells.
# Baseflow at: 7802 grid cells.
# Baseflow at: 7802 grid cells.
# Baseflow at: 7802 grid cells.
# Baseflow at: 7802 grid cells.
# Baseflow at: 7802 grid cells.
# Baseflow at: 7802 grid cells.
# Baseflow at: 12055 grid cells.
# Baseflow at: 12052 grid cells.
# Baseflow at: 12052 grid cells.
# Baseflow at: 12052 grid cells.
# Time =   16035.00 [min],  Q_out =  253.90724 [m^3/s]
# Baseflow at: 12052 grid cells.
# Baseflow at: 12052 grid cells.
# Baseflow at: 12130 grid cells.
# Baseflow at: 12129 grid cells.
# Baseflow at: 12129 grid cells.
# Baseflow at: 12129 grid cells.
# Baseflow at: 12129 grid cells.
# Baseflow at: 12129 grid cells.
# Baseflow at: 12101 grid cells.
# Baseflow at: 12101 grid cells.
# Baseflow at: 12101 grid cells.
# Time =   16680.00 [min],  Q_out =  376.35901 [m^3/s]
# Baseflow at: 12101 grid cells.
# Baseflow at: 12101 grid cells.
# Baseflow at: 12101 grid cells.
# Baseflow at: 10581 grid cells.
# Baseflow at: 10580 grid cells.
# Baseflow at: 10580 grid cells.
# Baseflow at: 10580 grid cells.
# Baseflow at: 10580 grid cells.
# Baseflow at: 10580 grid cells.
# Baseflow at: 7829 grid cells.
# Time =   17328.33 [min],  Q_out =  384.27303 [m^3/s]
# Baseflow at: 7829 grid cells.
# Baseflow at: 7829 grid cells.
# Baseflow at: 7829 grid cells.
# Baseflow at: 7829 grid cells.
# Baseflow at: 7829 grid cells.
# Baseflow at: 7766 grid cells.
# Baseflow at: 7766 grid cells.
# Baseflow at: 7766 grid cells.
# Baseflow at: 7766 grid cells.
# Baseflow at: 7766 grid cells.
# Time =   17880.00 [min],  Q_out =  378.50247 [m^3/s]
# Baseflow at: 7766 grid cells.
# Baseflow at: 7768 grid cells.
# Baseflow at: 7768 grid cells.
# Baseflow at: 7768 grid cells.
# Baseflow at: 7768 grid cells.
# Baseflow at: 7768 grid cells.
# Baseflow at: 7768 grid cells.
# Baseflow at: 7773 grid cells.
# Baseflow at: 7773 grid cells.
# Time =   18420.00 [min],  Q_out =  369.91121 [m^3/s]
# Baseflow at: 7773 grid cells.
# Baseflow at: 7773 grid cells.
# Baseflow at: 7773 grid cells.
# Baseflow at: 7773 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Time =   18975.00 [min],  Q_out =  361.92236 [m^3/s]
# Baseflow at: 7730 grid cells.
# Baseflow at: 7728 grid cells.
# Baseflow at: 7728 grid cells.
# Baseflow at: 7728 grid cells.
# Baseflow at: 7728 grid cells.
# Baseflow at: 7728 grid cells.
# Baseflow at: 7728 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Time =   19560.00 [min],  Q_out =  356.25222 [m^3/s]
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Baseflow at: 7730 grid cells.
# Time =   20116.67 [min],  Q_out =  351.96211 [m^3/s]
# Baseflow at: 7848 grid cells.
# Baseflow at: 7848 grid cells.
# Baseflow at: 7848 grid cells.
# Baseflow at: 7848 grid cells.
# Baseflow at: 7848 grid cells.
# Baseflow at: 7848 grid cells.
# Baseflow at: 7847 grid cells.
# Baseflow at: 7847 grid cells.
# Baseflow at: 7847 grid cells.
# Time =   20670.00 [min],  Q_out =  347.55504 [m^3/s]
# Baseflow at: 7847 grid cells.
# Baseflow at: 7847 grid cells.
# Baseflow at: 7847 grid cells.
# Baseflow at: 7742 grid cells.
# Baseflow at: 7742 grid cells.
# Baseflow at: 7742 grid cells.
# Baseflow at: 7742 grid cells.
# Baseflow at: 7742 grid cells.
# Baseflow at: 7742 grid cells.
# Time =   21225.00 [min],  Q_out =  334.96251 [m^3/s]
# Baseflow at: 8052 grid cells.
# Baseflow at: 8052 grid cells.
# Baseflow at: 8052 grid cells.
# Baseflow at: 8052 grid cells.
# Baseflow at: 8052 grid cells.
# Baseflow at: 8052 grid cells.
# Baseflow at: 8975 grid cells.
# Baseflow at: 8973 grid cells.
# Baseflow at: 8973 grid cells.
# Baseflow at: 8973 grid cells.
# Time =   21780.00 [min],  Q_out =  298.86340 [m^3/s]
# Baseflow at: 8973 grid cells.
# Baseflow at: 8973 grid cells.
# Baseflow at: 9682 grid cells.
# Baseflow at: 9682 grid cells.
# Baseflow at: 9682 grid cells.
# Baseflow at: 9682 grid cells.
# Baseflow at: 9682 grid cells.
# Baseflow at: 9682 grid cells.
# Baseflow at: 10300 grid cells.
# Time =   22350.00 [min],  Q_out =  264.82179 [m^3/s]
# Baseflow at: 10299 grid cells.
# Baseflow at: 10299 grid cells.
# Baseflow at: 10299 grid cells.
# Baseflow at: 10299 grid cells.
# Baseflow at: 10299 grid cells.
# Baseflow at: 9275 grid cells.
# Baseflow at: 9275 grid cells.
# Baseflow at: 9275 grid cells.
# Baseflow at: 9275 grid cells.
# Time =   22905.00 [min],  Q_out =  234.34761 [m^3/s]
# Baseflow at: 9275 grid cells.
# Baseflow at: 9275 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 8213 grid cells.
# Baseflow at: 8213 grid cells.
# Time =   23475.00 [min],  Q_out =  206.15008 [m^3/s]
# Baseflow at: 8213 grid cells.
# Baseflow at: 8213 grid cells.
# Baseflow at: 8213 grid cells.
# Baseflow at: 8213 grid cells.
# Baseflow at: 8170 grid cells.
# Baseflow at: 8170 grid cells.
# Baseflow at: 8170 grid cells.
# Baseflow at: 8170 grid cells.
# Baseflow at: 8170 grid cells.
# Time =   24030.00 [min],  Q_out =  184.60367 [m^3/s]
# Baseflow at: 8170 grid cells.
# Baseflow at: 7986 grid cells.
# Baseflow at: 7986 grid cells.
# Baseflow at: 7986 grid cells.
# Baseflow at: 7986 grid cells.
# Baseflow at: 7986 grid cells.
# Baseflow at: 7986 grid cells.
# Baseflow at: 8182 grid cells.
# Baseflow at: 8182 grid cells.
# Baseflow at: 8182 grid cells.
# Baseflow at: 8182 grid cells.
# Time =   24660.00 [min],  Q_out =  167.30473 [m^3/s]
# Baseflow at: 8182 grid cells.
# Baseflow at: 8182 grid cells.
# Baseflow at: 8202 grid cells.
# Baseflow at: 8202 grid cells.
# Baseflow at: 8202 grid cells.
# Baseflow at: 8202 grid cells.
# Baseflow at: 8202 grid cells.
# Baseflow at: 8202 grid cells.
# Baseflow at: 8208 grid cells.
# Time =   25245.00 [min],  Q_out =  153.18087 [m^3/s]
# Baseflow at: 8208 grid cells.
# Baseflow at: 8208 grid cells.
# Baseflow at: 8208 grid cells.
# Baseflow at: 8208 grid cells.
# Baseflow at: 8208 grid cells.
# Baseflow at: 8101 grid cells.
# Baseflow at: 8101 grid cells.
# Baseflow at: 8101 grid cells.
# Baseflow at: 8101 grid cells.
# Baseflow at: 8101 grid cells.
# Baseflow at: 8101 grid cells.
# Time =   25860.00 [min],  Q_out =  145.32183 [m^3/s]
# Baseflow at: 7754 grid cells.
# Baseflow at: 7754 grid cells.
# Baseflow at: 7754 grid cells.
# Baseflow at: 7754 grid cells.
# Baseflow at: 7754 grid cells.
# Baseflow at: 7754 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Time =   26385.00 [min],  Q_out =  154.76519 [m^3/s]
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7811 grid cells.
# Baseflow at: 7811 grid cells.
# Baseflow at: 7811 grid cells.
# Baseflow at: 7811 grid cells.
# Baseflow at: 7811 grid cells.
# Baseflow at: 7811 grid cells.
# Time =   26940.00 [min],  Q_out =  157.43310 [m^3/s]
# Baseflow at: 7846 grid cells.
# Baseflow at: 7846 grid cells.
# Baseflow at: 7846 grid cells.
# Baseflow at: 7846 grid cells.
# Baseflow at: 7846 grid cells.
# Baseflow at: 7846 grid cells.
# Baseflow at: 7738 grid cells.
# Baseflow at: 7738 grid cells.
# Baseflow at: 7738 grid cells.
# Baseflow at: 7738 grid cells.
# Time =   27570.00 [min],  Q_out =  172.63186 [m^3/s]
# Baseflow at: 7738 grid cells.
# Baseflow at: 7738 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Time =   28260.00 [min],  Q_out =  281.97786 [m^3/s]
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7737 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7736 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Time =   28935.00 [min],  Q_out =  263.86045 [m^3/s]
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Time =   29505.00 [min],  Q_out =  256.51241 [m^3/s]
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Baseflow at: 7732 grid cells.
# Time =   30165.00 [min],  Q_out =  261.35629 [m^3/s]
# Baseflow at: 7732 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7860 grid cells.
# Baseflow at: 7860 grid cells.
# Baseflow at: 7860 grid cells.
# Baseflow at: 7860 grid cells.
# Time =   30795.00 [min],  Q_out =  222.94058 [m^3/s]
# Baseflow at: 7860 grid cells.
# Baseflow at: 7860 grid cells.
# Baseflow at: 7870 grid cells.
# Baseflow at: 7870 grid cells.
# Baseflow at: 7870 grid cells.
# Baseflow at: 7870 grid cells.
# Baseflow at: 7870 grid cells.
# Baseflow at: 7870 grid cells.
# Baseflow at: 7934 grid cells.
# Baseflow at: 7934 grid cells.
# Baseflow at: 7934 grid cells.
# Time =   31470.00 [min],  Q_out =  182.35512 [m^3/s]
# Baseflow at: 7934 grid cells.
# Baseflow at: 7934 grid cells.
# Baseflow at: 7934 grid cells.
# Baseflow at: 8649 grid cells.
# Baseflow at: 8647 grid cells.
# Baseflow at: 8647 grid cells.
# Baseflow at: 8647 grid cells.
# Baseflow at: 8647 grid cells.
# Baseflow at: 8647 grid cells.
# Baseflow at: 8276 grid cells.
# Baseflow at: 8276 grid cells.
# Time =   32145.00 [min],  Q_out =  154.27760 [m^3/s]
# Baseflow at: 8276 grid cells.
# Baseflow at: 8276 grid cells.
# Baseflow at: 8276 grid cells.
# Baseflow at: 8276 grid cells.
# Baseflow at: 8237 grid cells.
# Baseflow at: 8237 grid cells.
# Baseflow at: 8237 grid cells.
# Baseflow at: 8237 grid cells.
# Baseflow at: 8237 grid cells.
# Baseflow at: 8237 grid cells.
# Baseflow at: 8575 grid cells.
# Baseflow at: 8575 grid cells.
# Time =   32820.00 [min],  Q_out =  135.62393 [m^3/s]
# Baseflow at: 8575 grid cells.
# Baseflow at: 8575 grid cells.
# Baseflow at: 8575 grid cells.
# Baseflow at: 8575 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Time =   33480.00 [min],  Q_out =  122.10663 [m^3/s]
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7798 grid cells.
# Baseflow at: 7759 grid cells.
# Baseflow at: 7759 grid cells.
# Baseflow at: 7759 grid cells.
# Baseflow at: 7759 grid cells.
# Baseflow at: 7759 grid cells.
# Time =   34105.00 [min],  Q_out =  111.77984 [m^3/s]
# Baseflow at: 7759 grid cells.
# Baseflow at: 7735 grid cells.
# Baseflow at: 7735 grid cells.
# Baseflow at: 7735 grid cells.
# Baseflow at: 7735 grid cells.
# Baseflow at: 7735 grid cells.
# Baseflow at: 7735 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7740 grid cells.
# Time =   34785.00 [min],  Q_out =  101.53087 [m^3/s]
# Baseflow at: 7740 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7744 grid cells.
# Baseflow at: 7744 grid cells.
# Baseflow at: 7744 grid cells.
# Baseflow at: 7744 grid cells.
# Time =   35460.00 [min],  Q_out =   92.47948 [m^3/s]
# Baseflow at: 7744 grid cells.
# Baseflow at: 7744 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7854 grid cells.
# Baseflow at: 7853 grid cells.
# Baseflow at: 7853 grid cells.
# Time =   36148.33 [min],  Q_out =   84.90005 [m^3/s]
# Baseflow at: 7853 grid cells.
# Baseflow at: 7853 grid cells.
# Baseflow at: 7853 grid cells.
# Baseflow at: 7923 grid cells.
# Baseflow at: 7923 grid cells.
# Baseflow at: 7923 grid cells.
# Baseflow at: 7923 grid cells.
# Baseflow at: 7923 grid cells.
# Baseflow at: 7923 grid cells.
# Baseflow at: 7924 grid cells.
# Time =   36765.00 [min],  Q_out =   80.72970 [m^3/s]
# Baseflow at: 7924 grid cells.
# Baseflow at: 7924 grid cells.
# Baseflow at: 7924 grid cells.
# Baseflow at: 7924 grid cells.
# Baseflow at: 7924 grid cells.
# Baseflow at: 7767 grid cells.
# Baseflow at: 7767 grid cells.
# Baseflow at: 7767 grid cells.
# Baseflow at: 7767 grid cells.
# Baseflow at: 7767 grid cells.
# Baseflow at: 7767 grid cells.
# Time =   37433.33 [min],  Q_out =   94.14835 [m^3/s]
# Baseflow at: 8129 grid cells.
# Baseflow at: 8128 grid cells.
# Baseflow at: 8128 grid cells.
# Baseflow at: 8128 grid cells.
# Baseflow at: 8128 grid cells.
# Baseflow at: 8128 grid cells.
# Baseflow at: 8310 grid cells.
# Baseflow at: 8310 grid cells.
# Baseflow at: 8310 grid cells.
# Baseflow at: 8310 grid cells.
# Baseflow at: 8310 grid cells.
# Baseflow at: 8310 grid cells.
# Time =   38100.00 [min],  Q_out =  125.04354 [m^3/s]
# Baseflow at: 8374 grid cells.
# Baseflow at: 8374 grid cells.
# Baseflow at: 8374 grid cells.
# Baseflow at: 8374 grid cells.
# Baseflow at: 8374 grid cells.
# Baseflow at: 8374 grid cells.
# Baseflow at: 8272 grid cells.
# Baseflow at: 8272 grid cells.
# Baseflow at: 8272 grid cells.
# Baseflow at: 8272 grid cells.
# Baseflow at: 8272 grid cells.
# Time =   38800.00 [min],  Q_out =  141.69740 [m^3/s]
# Baseflow at: 8272 grid cells.
# Baseflow at: 7841 grid cells.
# Baseflow at: 7839 grid cells.
# Baseflow at: 7839 grid cells.
# Baseflow at: 7839 grid cells.
# Baseflow at: 7839 grid cells.
# Baseflow at: 7839 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7882 grid cells.
# Baseflow at: 7882 grid cells.
# Time =   39480.00 [min],  Q_out =  142.55721 [m^3/s]
# Baseflow at: 7882 grid cells.
# Baseflow at: 7971 grid cells.
# Baseflow at: 7972 grid cells.
# Baseflow at: 7971 grid cells.
# Baseflow at: 7971 grid cells.
# Baseflow at: 7971 grid cells.
# Baseflow at: 7971 grid cells.
# Baseflow at: 8061 grid cells.
# Baseflow at: 8061 grid cells.
# Baseflow at: 8061 grid cells.
# Baseflow at: 8061 grid cells.
# Time =   40170.00 [min],  Q_out =  130.74575 [m^3/s]
# Baseflow at: 8061 grid cells.
# Baseflow at: 8061 grid cells.
# Baseflow at: 8423 grid cells.
# Baseflow at: 8423 grid cells.
# Baseflow at: 8423 grid cells.
# Baseflow at: 8423 grid cells.
# Baseflow at: 8423 grid cells.
# Baseflow at: 8423 grid cells.
# Baseflow at: 8156 grid cells.
# Baseflow at: 8156 grid cells.
# Baseflow at: 8156 grid cells.
# Time =   40825.00 [min],  Q_out =  117.72658 [m^3/s]
# Baseflow at: 8156 grid cells.
# Baseflow at: 8156 grid cells.
# Baseflow at: 8156 grid cells.
# Baseflow at: 8266 grid cells.
# Baseflow at: 8266 grid cells.
# Baseflow at: 8266 grid cells.
# Baseflow at: 8266 grid cells.
# Baseflow at: 8266 grid cells.
# Baseflow at: 8266 grid cells.
# Baseflow at: 8448 grid cells.
# Baseflow at: 8448 grid cells.
# Time =   41490.00 [min],  Q_out =  106.30724 [m^3/s]
# Baseflow at: 8448 grid cells.
# Baseflow at: 8448 grid cells.
# Baseflow at: 8448 grid cells.
# Baseflow at: 8448 grid cells.
# Baseflow at: 8221 grid cells.
# Baseflow at: 8221 grid cells.
# Baseflow at: 8221 grid cells.
# Baseflow at: 8221 grid cells.
# Baseflow at: 8221 grid cells.
# Baseflow at: 8221 grid cells.
# Baseflow at: 8406 grid cells.
# Baseflow at: 8406 grid cells.
# Time =   42180.00 [min],  Q_out =   96.46824 [m^3/s]
# Baseflow at: 8406 grid cells.
# Baseflow at: 8406 grid cells.
# Baseflow at: 8406 grid cells.
# Baseflow at: 8406 grid cells.
# Baseflow at: 8861 grid cells.
# Baseflow at: 8862 grid cells.
# Baseflow at: 8861 grid cells.
# Baseflow at: 8861 grid cells.
# Baseflow at: 8861 grid cells.
# Baseflow at: 8861 grid cells.
# Baseflow at: 9587 grid cells.
# Time =   42855.00 [min],  Q_out =   89.16300 [m^3/s]
# Baseflow at: 9587 grid cells.
# Baseflow at: 9587 grid cells.
# Baseflow at: 9587 grid cells.
# Baseflow at: 9587 grid cells.
# Baseflow at: 9587 grid cells.
# Baseflow at: 12304 grid cells.
# Baseflow at: 12304 grid cells.
# Baseflow at: 12304 grid cells.
# Baseflow at: 12304 grid cells.
# Baseflow at: 12304 grid cells.
# Baseflow at: 12304 grid cells.
# Time =   43558.33 [min],  Q_out =   96.16980 [m^3/s]
# Baseflow at: 12101 grid cells.
# Baseflow at: 12101 grid cells.
# Baseflow at: 12101 grid cells.
# Baseflow at: 12101 grid cells.
# Baseflow at: 12101 grid cells.
# Baseflow at: 12101 grid cells.
# Baseflow at: 11853 grid cells.
# Baseflow at: 11852 grid cells.
# Baseflow at: 11852 grid cells.
# Baseflow at: 11852 grid cells.
# Baseflow at: 11852 grid cells.
# Baseflow at: 11852 grid cells.
# Time =   44241.67 [min],  Q_out =  172.74187 [m^3/s]
# Baseflow at: 12978 grid cells.
# Baseflow at: 12978 grid cells.
# Baseflow at: 12978 grid cells.
# Baseflow at: 12978 grid cells.
# Baseflow at: 12978 grid cells.
# Baseflow at: 12978 grid cells.
# Baseflow at: 13329 grid cells.
# Baseflow at: 13329 grid cells.
# Baseflow at: 13329 grid cells.
# Baseflow at: 13329 grid cells.
# Baseflow at: 13329 grid cells.
# Baseflow at: 13329 grid cells.
# Time =   44940.00 [min],  Q_out =  290.59443 [m^3/s]
# Baseflow at: 13436 grid cells.
# Baseflow at: 13436 grid cells.
# Baseflow at: 13436 grid cells.
# Baseflow at: 13436 grid cells.
# Baseflow at: 13436 grid cells.
# Baseflow at: 13436 grid cells.
# Baseflow at: 13227 grid cells.
# Baseflow at: 13227 grid cells.
# Baseflow at: 13227 grid cells.
# Baseflow at: 13227 grid cells.
# Baseflow at: 13227 grid cells.
# Time =   45630.00 [min],  Q_out =  308.07058 [m^3/s]
# Baseflow at: 13227 grid cells.
# Baseflow at: 13131 grid cells.
# Baseflow at: 13131 grid cells.
# Baseflow at: 13131 grid cells.
# Baseflow at: 13131 grid cells.
# Baseflow at: 13131 grid cells.
# Baseflow at: 13131 grid cells.
# Baseflow at: 9692 grid cells.
# Baseflow at: 9692 grid cells.
# Baseflow at: 9692 grid cells.
# Baseflow at: 9692 grid cells.
# Baseflow at: 9692 grid cells.
# Time =   46320.00 [min],  Q_out =  308.57261 [m^3/s]
# Baseflow at: 9692 grid cells.
# Baseflow at: 10104 grid cells.
# Baseflow at: 10104 grid cells.
# Baseflow at: 10104 grid cells.
# Baseflow at: 10104 grid cells.
# Baseflow at: 10104 grid cells.
# Baseflow at: 10104 grid cells.
# Baseflow at: 10105 grid cells.
# Baseflow at: 10105 grid cells.
# Baseflow at: 10105 grid cells.
# Baseflow at: 10105 grid cells.
# Time =   47010.00 [min],  Q_out =  308.88935 [m^3/s]
# Baseflow at: 10105 grid cells.
# Baseflow at: 10105 grid cells.
# Baseflow at: 10005 grid cells.
# Baseflow at: 10005 grid cells.
# Baseflow at: 10005 grid cells.
# Baseflow at: 10005 grid cells.
# Baseflow at: 10005 grid cells.
# Baseflow at: 10005 grid cells.
# Baseflow at: 9792 grid cells.
# Baseflow at: 9792 grid cells.
# Baseflow at: 9792 grid cells.
# Time =   47670.00 [min],  Q_out =  309.01882 [m^3/s]
# Baseflow at: 9792 grid cells.
# Baseflow at: 9792 grid cells.
# Baseflow at: 9792 grid cells.
# Baseflow at: 10177 grid cells.
# Baseflow at: 10177 grid cells.
# Baseflow at: 10177 grid cells.
# Baseflow at: 10177 grid cells.
# Baseflow at: 10177 grid cells.
# Baseflow at: 10177 grid cells.
# Baseflow at: 10083 grid cells.
# Baseflow at: 10083 grid cells.
# Time =   48358.33 [min],  Q_out =  309.08459 [m^3/s]
# Baseflow at: 10083 grid cells.
# Baseflow at: 10083 grid cells.
# Baseflow at: 10084 grid cells.
# Baseflow at: 10084 grid cells.
# Baseflow at: 9784 grid cells.
# Baseflow at: 9784 grid cells.
# Baseflow at: 9784 grid cells.
# Baseflow at: 9784 grid cells.
# Baseflow at: 9784 grid cells.
# Baseflow at: 9784 grid cells.
# Baseflow at: 9733 grid cells.
# Baseflow at: 9733 grid cells.
# Time =   49020.00 [min],  Q_out =  309.12424 [m^3/s]
# Baseflow at: 9733 grid cells.
# Baseflow at: 9733 grid cells.
# Baseflow at: 9733 grid cells.
# Baseflow at: 9733 grid cells.
# Baseflow at: 9674 grid cells.
# Baseflow at: 9674 grid cells.
# Baseflow at: 9674 grid cells.
# Baseflow at: 9674 grid cells.
# Baseflow at: 9674 grid cells.
# Baseflow at: 9674 grid cells.
# Baseflow at: 9738 grid cells.
# Time =   49725.00 [min],  Q_out =  309.13337 [m^3/s]
# Baseflow at: 9738 grid cells.
# Baseflow at: 9738 grid cells.
# Baseflow at: 9738 grid cells.
# Baseflow at: 9738 grid cells.
# Baseflow at: 9738 grid cells.
# Baseflow at: 9888 grid cells.
# Baseflow at: 9888 grid cells.
# Baseflow at: 9888 grid cells.
# Baseflow at: 9888 grid cells.
# Baseflow at: 9888 grid cells.
# Baseflow at: 9888 grid cells.
# Baseflow at: 9637 grid cells.
# Time =   50415.00 [min],  Q_out =  309.10453 [m^3/s]
# Baseflow at: 9637 grid cells.
# Baseflow at: 9637 grid cells.
# Baseflow at: 9637 grid cells.
# Baseflow at: 9637 grid cells.
# Baseflow at: 9637 grid cells.
# Baseflow at: 9616 grid cells.
# Baseflow at: 9616 grid cells.
# Baseflow at: 9616 grid cells.
# Baseflow at: 9616 grid cells.
# Baseflow at: 9615 grid cells.
# Baseflow at: 9615 grid cells.
# Time =   51105.00 [min],  Q_out =  309.04212 [m^3/s]
# Baseflow at: 8832 grid cells.
# Baseflow at: 8832 grid cells.
# Baseflow at: 8832 grid cells.
# Baseflow at: 8832 grid cells.
# Baseflow at: 8832 grid cells.
# Baseflow at: 8832 grid cells.
# Baseflow at: 8879 grid cells.
# Baseflow at: 8879 grid cells.
# Baseflow at: 8879 grid cells.
# Baseflow at: 8879 grid cells.
# Baseflow at: 8879 grid cells.
# Baseflow at: 8879 grid cells.
# Time =   51795.00 [min],  Q_out =  308.95375 [m^3/s]
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7885 grid cells.
# Baseflow at: 7972 grid cells.
# Baseflow at: 7972 grid cells.
# Baseflow at: 7972 grid cells.
# Baseflow at: 7972 grid cells.
# Baseflow at: 7972 grid cells.
# Time =   52470.00 [min],  Q_out =  308.73945 [m^3/s]
# Baseflow at: 7972 grid cells.
# Baseflow at: 8009 grid cells.
# Baseflow at: 8009 grid cells.
# Baseflow at: 8009 grid cells.
# Baseflow at: 8009 grid cells.
# Baseflow at: 8009 grid cells.
# Baseflow at: 8009 grid cells.
# Baseflow at: 7794 grid cells.
# Baseflow at: 7794 grid cells.
# Baseflow at: 7793 grid cells.
# Baseflow at: 7793 grid cells.
# Time =   53145.00 [min],  Q_out =  308.73149 [m^3/s]
# Baseflow at: 7794 grid cells.
# Baseflow at: 7794 grid cells.
# Baseflow at: 7740 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7741 grid cells.
# Baseflow at: 7748 grid cells.
# Baseflow at: 7748 grid cells.
# Baseflow at: 7748 grid cells.
# Baseflow at: 7748 grid cells.
# Time =   53820.00 [min],  Q_out =  308.56924 [m^3/s]
# Baseflow at: 7748 grid cells.
# Baseflow at: 7748 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7757 grid cells.
# Baseflow at: 7757 grid cells.
# Baseflow at: 7757 grid cells.
# Time =   54495.00 [min],  Q_out =  307.40182 [m^3/s]
# Baseflow at: 7757 grid cells.
# Baseflow at: 7757 grid cells.
# Baseflow at: 7757 grid cells.
# Baseflow at: 8057 grid cells.
# Baseflow at: 8057 grid cells.
# Baseflow at: 8057 grid cells.
# Baseflow at: 8057 grid cells.
# Baseflow at: 8057 grid cells.
# Baseflow at: 8057 grid cells.
# Baseflow at: 8344 grid cells.
# Baseflow at: 8344 grid cells.
# Time =   55170.00 [min],  Q_out =  298.58562 [m^3/s]
# Baseflow at: 8344 grid cells.
# Baseflow at: 8344 grid cells.
# Baseflow at: 8344 grid cells.
# Baseflow at: 8344 grid cells.
# Baseflow at: 8305 grid cells.
# Baseflow at: 8305 grid cells.
# Baseflow at: 8305 grid cells.
# Baseflow at: 8305 grid cells.
# Baseflow at: 8305 grid cells.
# Baseflow at: 8305 grid cells.
# Baseflow at: 8011 grid cells.
# Time =   55845.00 [min],  Q_out =  288.13718 [m^3/s]
# Baseflow at: 8011 grid cells.
# Baseflow at: 8011 grid cells.
# Baseflow at: 8011 grid cells.
# Baseflow at: 8011 grid cells.
# Baseflow at: 8011 grid cells.
# Baseflow at: 11529 grid cells.
# Baseflow at: 11529 grid cells.
# Baseflow at: 11529 grid cells.
# Baseflow at: 11529 grid cells.
# Baseflow at: 11529 grid cells.
# Baseflow at: 11529 grid cells.
# Baseflow at: 11965 grid cells.
# Time =   56535.00 [min],  Q_out =  281.22071 [m^3/s]
# Baseflow at: 11965 grid cells.
# Baseflow at: 11965 grid cells.
# Baseflow at: 11965 grid cells.
# Baseflow at: 11965 grid cells.
# Baseflow at: 11965 grid cells.
# Baseflow at: 11990 grid cells.
# Baseflow at: 11990 grid cells.
# Baseflow at: 11990 grid cells.
# Baseflow at: 11990 grid cells.
# Baseflow at: 11990 grid cells.
# Baseflow at: 11990 grid cells.
# Time =   57233.33 [min],  Q_out =  301.38741 [m^3/s]
# Baseflow at: 11647 grid cells.
# Baseflow at: 11647 grid cells.
# Baseflow at: 11647 grid cells.
# Baseflow at: 11647 grid cells.
# Baseflow at: 11647 grid cells.
# Baseflow at: 11647 grid cells.
# Baseflow at: 10109 grid cells.
# Baseflow at: 10109 grid cells.
# Baseflow at: 10109 grid cells.
# Baseflow at: 10109 grid cells.
# Baseflow at: 10109 grid cells.
# Baseflow at: 10109 grid cells.
# Time =   57915.00 [min],  Q_out =  269.59173 [m^3/s]
# Baseflow at: 10541 grid cells.
# Baseflow at: 10541 grid cells.
# Baseflow at: 10541 grid cells.
# Baseflow at: 10541 grid cells.
# Baseflow at: 10541 grid cells.
# Baseflow at: 10541 grid cells.
# Baseflow at: 10621 grid cells.
# Baseflow at: 10622 grid cells.
# Baseflow at: 10622 grid cells.
# Baseflow at: 10622 grid cells.
# Baseflow at: 10622 grid cells.
# Baseflow at: 10622 grid cells.
# Time =   58620.00 [min],  Q_out =  233.44954 [m^3/s]
# Baseflow at: 10157 grid cells.
# Baseflow at: 10156 grid cells.
# Baseflow at: 10156 grid cells.
# Baseflow at: 10156 grid cells.
# Baseflow at: 10156 grid cells.
# Baseflow at: 10156 grid cells.
# Baseflow at: 8730 grid cells.
# Baseflow at: 8730 grid cells.
# Baseflow at: 8730 grid cells.
# Baseflow at: 8730 grid cells.
# Baseflow at: 8730 grid cells.
# Time =   59305.00 [min],  Q_out =  216.25524 [m^3/s]
# Baseflow at: 8730 grid cells.
# Baseflow at: 9569 grid cells.
# Baseflow at: 9569 grid cells.
# Baseflow at: 9569 grid cells.
# Baseflow at: 9569 grid cells.
# Baseflow at: 9569 grid cells.
# Baseflow at: 9569 grid cells.
# Baseflow at: 9534 grid cells.
# Baseflow at: 9534 grid cells.
# Baseflow at: 9534 grid cells.
# Baseflow at: 9534 grid cells.
# Time =   59985.00 [min],  Q_out =  193.80803 [m^3/s]
# Baseflow at: 9534 grid cells.
# Baseflow at: 9534 grid cells.
# Baseflow at: 8794 grid cells.
# Baseflow at: 8794 grid cells.
# Baseflow at: 8794 grid cells.
# Baseflow at: 8794 grid cells.
# Baseflow at: 8794 grid cells.
# Baseflow at: 8794 grid cells.
# Baseflow at: 7769 grid cells.
# Baseflow at: 7769 grid cells.
# Baseflow at: 7769 grid cells.
# Baseflow at: 7769 grid cells.
# Time =   60660.00 [min],  Q_out =  291.20221 [m^3/s]
# Baseflow at: 7769 grid cells.
# Baseflow at: 7769 grid cells.
# Baseflow at: 7852 grid cells.
# Baseflow at: 7852 grid cells.
# Baseflow at: 7851 grid cells.
# Baseflow at: 7851 grid cells.
# Baseflow at: 7851 grid cells.
# Baseflow at: 7851 grid cells.
# Baseflow at: 7835 grid cells.
# Baseflow at: 7835 grid cells.
# Baseflow at: 7835 grid cells.
# Time =   61350.00 [min],  Q_out =  290.08386 [m^3/s]
# Baseflow at: 7835 grid cells.
# Baseflow at: 7835 grid cells.
# Baseflow at: 7835 grid cells.
# Baseflow at: 7774 grid cells.
# Baseflow at: 7774 grid cells.
# Baseflow at: 7774 grid cells.
# Baseflow at: 7774 grid cells.
# Baseflow at: 7774 grid cells.
# Baseflow at: 7774 grid cells.
# Baseflow at: 9542 grid cells.
# Baseflow at: 9542 grid cells.
# Baseflow at: 9542 grid cells.
# Time =   62040.00 [min],  Q_out =  281.08549 [m^3/s]
# Baseflow at: 9542 grid cells.
# Baseflow at: 9542 grid cells.
# Baseflow at: 9542 grid cells.
# Baseflow at: 9672 grid cells.
# Baseflow at: 9672 grid cells.
# Baseflow at: 9672 grid cells.
# Baseflow at: 9672 grid cells.
# Baseflow at: 9672 grid cells.
# Baseflow at: 9672 grid cells.
# Baseflow at: 9685 grid cells.
# Baseflow at: 9685 grid cells.
# Time =   62730.00 [min],  Q_out =  273.23218 [m^3/s]
# Baseflow at: 9685 grid cells.
# Baseflow at: 9685 grid cells.
# Baseflow at: 9685 grid cells.
# Baseflow at: 9685 grid cells.
# Baseflow at: 9355 grid cells.
# Baseflow at: 9355 grid cells.
# Baseflow at: 9355 grid cells.
# Baseflow at: 9355 grid cells.
# Baseflow at: 9355 grid cells.
# Baseflow at: 9355 grid cells.
# Baseflow at: 11625 grid cells.
# Baseflow at: 11625 grid cells.
# Time =   63420.00 [min],  Q_out =  303.67173 [m^3/s]
# Baseflow at: 11625 grid cells.
# Baseflow at: 11625 grid cells.
# Baseflow at: 11625 grid cells.
# Baseflow at: 11625 grid cells.
# Baseflow at: 11734 grid cells.
# Baseflow at: 11733 grid cells.
# Baseflow at: 11733 grid cells.
# Baseflow at: 11733 grid cells.
# Baseflow at: 11733 grid cells.
# Baseflow at: 11733 grid cells.
# Baseflow at: 11818 grid cells.
# Time =   64125.00 [min],  Q_out =  307.81944 [m^3/s]
# Baseflow at: 11818 grid cells.
# Baseflow at: 11818 grid cells.
# Baseflow at: 11818 grid cells.
# Baseflow at: 11818 grid cells.
# Baseflow at: 11818 grid cells.
# Baseflow at: 11871 grid cells.
# Baseflow at: 11871 grid cells.
# Baseflow at: 11871 grid cells.
# Baseflow at: 11871 grid cells.
# Baseflow at: 11871 grid cells.
# Baseflow at: 11871 grid cells.
# Baseflow at: 9275 grid cells.
# Time =   64815.00 [min],  Q_out =  307.82592 [m^3/s]
# Baseflow at: 9275 grid cells.
# Baseflow at: 9275 grid cells.
# Baseflow at: 9275 grid cells.
# Baseflow at: 9275 grid cells.
# Baseflow at: 9275 grid cells.
# Baseflow at: 9552 grid cells.
# Baseflow at: 9552 grid cells.
# Baseflow at: 9552 grid cells.
# Baseflow at: 9552 grid cells.
# Baseflow at: 9552 grid cells.
# Baseflow at: 9552 grid cells.
# Time =   65493.33 [min],  Q_out =  308.16183 [m^3/s]
# Baseflow at: 9577 grid cells.
# Baseflow at: 9577 grid cells.
# Baseflow at: 9577 grid cells.
# Baseflow at: 9577 grid cells.
# Baseflow at: 9577 grid cells.
# Baseflow at: 9577 grid cells.
# Baseflow at: 9594 grid cells.
# Baseflow at: 9594 grid cells.
# Baseflow at: 9594 grid cells.
# Baseflow at: 9594 grid cells.
# Baseflow at: 9594 grid cells.
# Time =   66120.00 [min],  Q_out =  308.46184 [m^3/s]
# Baseflow at: 9594 grid cells.
# Baseflow at: 11686 grid cells.
# Baseflow at: 11686 grid cells.
# Baseflow at: 11686 grid cells.
# Baseflow at: 11686 grid cells.
# Baseflow at: 11686 grid cells.
# Baseflow at: 11686 grid cells.
# Baseflow at: 11775 grid cells.
# Baseflow at: 11775 grid cells.
# Baseflow at: 11775 grid cells.
# Baseflow at: 11775 grid cells.
# Time =   66825.00 [min],  Q_out =  313.55442 [m^3/s]
# Baseflow at: 11775 grid cells.
# Baseflow at: 11775 grid cells.
# Baseflow at: 11847 grid cells.
# Baseflow at: 11847 grid cells.
# Baseflow at: 11847 grid cells.
# Baseflow at: 11847 grid cells.
# Baseflow at: 11847 grid cells.
# Baseflow at: 11847 grid cells.
# Baseflow at: 11626 grid cells.
# Baseflow at: 11626 grid cells.
# Baseflow at: 11626 grid cells.
# Baseflow at: 11626 grid cells.
# Time =   67500.00 [min],  Q_out =  309.71256 [m^3/s]
# Baseflow at: 11626 grid cells.
# Baseflow at: 11626 grid cells.
# Baseflow at: 13560 grid cells.
# Baseflow at: 13560 grid cells.
# Baseflow at: 13560 grid cells.
# Baseflow at: 13560 grid cells.
# Baseflow at: 13560 grid cells.
# Baseflow at: 13560 grid cells.
# Baseflow at: 13690 grid cells.
# Baseflow at: 13690 grid cells.
# Baseflow at: 13690 grid cells.
# Time =   68176.67 [min],  Q_out =  313.26085 [m^3/s]
# Baseflow at: 13690 grid cells.
# Baseflow at: 13690 grid cells.
# Baseflow at: 13690 grid cells.
# Baseflow at: 13044 grid cells.
# Baseflow at: 13044 grid cells.
# Baseflow at: 13044 grid cells.
# Baseflow at: 13044 grid cells.
# Baseflow at: 13044 grid cells.
# Baseflow at: 13044 grid cells.
# Baseflow at: 12938 grid cells.
# Baseflow at: 12938 grid cells.
# Baseflow at: 12938 grid cells.
# Time =   68880.00 [min],  Q_out =  311.54431 [m^3/s]
# Baseflow at: 12938 grid cells.
# ...
# Baseflow at: 9745 grid cells.
# Baseflow at: 9745 grid cells.
# Baseflow at: 9339 grid cells.
# Baseflow at: 9339 grid cells.
# Baseflow at: 9339 grid cells.
# Baseflow at: 9339 grid cells.
# Baseflow at: 9339 grid cells.
# Baseflow at: 9339 grid cells.
# Baseflow at: 8298 grid cells.
# Time =  503670.00 [min],  Q_out =  129.02603 [m^3/s]
# Baseflow at: 8298 grid cells.
# Baseflow at: 8298 grid cells.
# Baseflow at: 8298 grid cells.
# Baseflow at: 8298 grid cells.
# Baseflow at: 8298 grid cells.
# Baseflow at: 7744 grid cells.
# Baseflow at: 7744 grid cells.
# Baseflow at: 7744 grid cells.
# Baseflow at: 7744 grid cells.
# Baseflow at: 7744 grid cells.
# Time =  504240.00 [min],  Q_out =  120.99874 [m^3/s]
# Baseflow at: 7744 grid cells.
# Baseflow at: 7762 grid cells.
# Baseflow at: 7762 grid cells.
# Baseflow at: 7762 grid cells.
# Baseflow at: 7762 grid cells.
# Baseflow at: 7762 grid cells.
# Baseflow at: 7762 grid cells.
# Baseflow at: 7767 grid cells.
# Baseflow at: 7767 grid cells.
# Time =  504833.33 [min],  Q_out =  126.29597 [m^3/s]
# Baseflow at: 7767 grid cells.
# Baseflow at: 7767 grid cells.
# Baseflow at: 7767 grid cells.
# Baseflow at: 7767 grid cells.
# Baseflow at: 7756 grid cells.
# Baseflow at: 7756 grid cells.
# Baseflow at: 7756 grid cells.
# Baseflow at: 7756 grid cells.
# Baseflow at: 7756 grid cells.
# Baseflow at: 7756 grid cells.
# Time =  505410.00 [min],  Q_out =  142.32861 [m^3/s]
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7745 grid cells.
# Baseflow at: 7836 grid cells.
# Baseflow at: 7836 grid cells.
# Baseflow at: 7836 grid cells.
# Baseflow at: 7836 grid cells.
# Time =  505995.00 [min],  Q_out =  150.39992 [m^3/s]
# Baseflow at: 7836 grid cells.
# Baseflow at: 7836 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7751 grid cells.
# Baseflow at: 7751 grid cells.
# Time =  506580.00 [min],  Q_out =  151.24310 [m^3/s]
# Baseflow at: 7751 grid cells.
# Baseflow at: 7751 grid cells.
# Baseflow at: 7751 grid cells.
# Baseflow at: 7751 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Time =  507165.00 [min],  Q_out =  147.89717 [m^3/s]
# Baseflow at: 7747 grid cells.
# Baseflow at: 7760 grid cells.
# Baseflow at: 7760 grid cells.
# Baseflow at: 7760 grid cells.
# Baseflow at: 7760 grid cells.
# Baseflow at: 7760 grid cells.
# Baseflow at: 7760 grid cells.
# Baseflow at: 7751 grid cells.
# Baseflow at: 7751 grid cells.
# Baseflow at: 7751 grid cells.
# Time =  507738.33 [min],  Q_out =  136.22697 [m^3/s]
# Baseflow at: 7751 grid cells.
# Baseflow at: 7751 grid cells.
# Baseflow at: 7751 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 7747 grid cells.
# Baseflow at: 8086 grid cells.
# Time =  508320.00 [min],  Q_out =  122.55464 [m^3/s]
# Baseflow at: 8086 grid cells.
# Baseflow at: 8086 grid cells.
# Baseflow at: 8086 grid cells.
# Baseflow at: 8086 grid cells.
# Baseflow at: 8086 grid cells.
# Baseflow at: 8145 grid cells.
# Baseflow at: 8145 grid cells.
# Baseflow at: 8145 grid cells.
# Baseflow at: 8145 grid cells.
# Time =  508890.00 [min],  Q_out =  110.30976 [m^3/s]
# Baseflow at: 8145 grid cells.
# Baseflow at: 8145 grid cells.
# Baseflow at: 7813 grid cells.
# Baseflow at: 7813 grid cells.
# Baseflow at: 7813 grid cells.
# Baseflow at: 7813 grid cells.
# Baseflow at: 7813 grid cells.
# Baseflow at: 7813 grid cells.
# Baseflow at: 8014 grid cells.
# Baseflow at: 8014 grid cells.
# Time =  509460.00 [min],  Q_out =  100.91574 [m^3/s]
# Baseflow at: 8014 grid cells.
# Baseflow at: 8014 grid cells.
# Baseflow at: 8014 grid cells.
# Baseflow at: 8014 grid cells.
# Baseflow at: 9304 grid cells.
# Baseflow at: 9304 grid cells.
# Baseflow at: 9304 grid cells.
# Baseflow at: 9304 grid cells.
# Baseflow at: 9304 grid cells.
# Time =  510030.00 [min],  Q_out =  104.63224 [m^3/s]
# Baseflow at: 9304 grid cells.
# Baseflow at: 8995 grid cells.
# Baseflow at: 8995 grid cells.
# Baseflow at: 8995 grid cells.
# Baseflow at: 8995 grid cells.
# Baseflow at: 8995 grid cells.
# Baseflow at: 8995 grid cells.
# Baseflow at: 8045 grid cells.
# Baseflow at: 8045 grid cells.
# Baseflow at: 8045 grid cells.
# Time =  510600.00 [min],  Q_out =  128.07054 [m^3/s]
# Baseflow at: 8045 grid cells.
# Baseflow at: 8045 grid cells.
# Baseflow at: 8045 grid cells.
# Baseflow at: 8164 grid cells.
# Baseflow at: 8164 grid cells.
# Baseflow at: 8164 grid cells.
# Baseflow at: 8164 grid cells.
# Baseflow at: 8164 grid cells.
# Baseflow at: 8164 grid cells.
# Time =  511185.00 [min],  Q_out =  140.63120 [m^3/s]
# Baseflow at: 7863 grid cells.
# Baseflow at: 7863 grid cells.
# Baseflow at: 7863 grid cells.
# Baseflow at: 7863 grid cells.
# Baseflow at: 7863 grid cells.
# Baseflow at: 7863 grid cells.
# Baseflow at: 7933 grid cells.
# Baseflow at: 7933 grid cells.
# Baseflow at: 7933 grid cells.
# Baseflow at: 7933 grid cells.
# Time =  511740.00 [min],  Q_out =  152.39788 [m^3/s]
# Baseflow at: 7933 grid cells.
# Baseflow at: 7933 grid cells.
# Baseflow at: 7788 grid cells.
# Baseflow at: 7788 grid cells.
# Baseflow at: 7788 grid cells.
# Baseflow at: 7788 grid cells.
# Baseflow at: 7788 grid cells.
# Baseflow at: 7788 grid cells.
# Baseflow at: 7755 grid cells.
# Time =  512310.00 [min],  Q_out =  149.29131 [m^3/s]
# Baseflow at: 7755 grid cells.
# Baseflow at: 7755 grid cells.
# Baseflow at: 7755 grid cells.
# Baseflow at: 7755 grid cells.
# Baseflow at: 7755 grid cells.
# Baseflow at: 7785 grid cells.
# Baseflow at: 7785 grid cells.
# Baseflow at: 7785 grid cells.
# Baseflow at: 7785 grid cells.
# Baseflow at: 7785 grid cells.
# Time =  512880.00 [min],  Q_out =  143.65083 [m^3/s]
# Baseflow at: 7785 grid cells.
# Baseflow at: 8115 grid cells.
# Baseflow at: 8115 grid cells.
# Baseflow at: 8115 grid cells.
# Baseflow at: 8115 grid cells.
# Baseflow at: 8115 grid cells.
# Baseflow at: 8115 grid cells.
# Baseflow at: 7795 grid cells.
# Baseflow at: 7795 grid cells.
# Time =  513450.00 [min],  Q_out =  137.25093 [m^3/s]
# Baseflow at: 7795 grid cells.
# Baseflow at: 7795 grid cells.
# Baseflow at: 7795 grid cells.
# Baseflow at: 7795 grid cells.
# Baseflow at: 7792 grid cells.
# Baseflow at: 7792 grid cells.
# Baseflow at: 7792 grid cells.
# Baseflow at: 7792 grid cells.
# Baseflow at: 7792 grid cells.
# Baseflow at: 7792 grid cells.
# Time =  514020.00 [min],  Q_out =  129.57948 [m^3/s]
# Baseflow at: 7928 grid cells.
# Baseflow at: 7928 grid cells.
# Baseflow at: 7928 grid cells.
# Baseflow at: 7928 grid cells.
# Baseflow at: 7928 grid cells.
# Baseflow at: 7928 grid cells.
# Baseflow at: 7984 grid cells.
# Baseflow at: 7984 grid cells.
# Baseflow at: 7984 grid cells.
# Time =  514590.00 [min],  Q_out =  121.63263 [m^3/s]
# Baseflow at: 7984 grid cells.
# Baseflow at: 7984 grid cells.
# Baseflow at: 7984 grid cells.
# Baseflow at: 7927 grid cells.
# Baseflow at: 7927 grid cells.
# Baseflow at: 7927 grid cells.
# Baseflow at: 7927 grid cells.
# Baseflow at: 7927 grid cells.
# Baseflow at: 7927 grid cells.
# Baseflow at: 7889 grid cells.
# Time =  515160.00 [min],  Q_out =  115.61389 [m^3/s]
# Baseflow at: 7889 grid cells.
# Baseflow at: 7889 grid cells.
# Baseflow at: 7889 grid cells.
# Baseflow at: 7889 grid cells.
# Baseflow at: 7889 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Time =  515731.67 [min],  Q_out =  106.30974 [m^3/s]
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Time =  516300.00 [min],  Q_out =  106.77735 [m^3/s]
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Baseflow at: 7743 grid cells.
# Time =  516870.00 [min],  Q_out =  114.94706 [m^3/s]
# Baseflow at: 7743 grid cells.
# Baseflow at: 7853 grid cells.
# Baseflow at: 7853 grid cells.
# Baseflow at: 7853 grid cells.
# Baseflow at: 7853 grid cells.
# Baseflow at: 7853 grid cells.
# Baseflow at: 7853 grid cells.
# Baseflow at: 8076 grid cells.
# Baseflow at: 8075 grid cells.
# Baseflow at: 8075 grid cells.
# Time =  517440.00 [min],  Q_out =  116.51150 [m^3/s]
# Baseflow at: 8075 grid cells.
# Baseflow at: 8075 grid cells.
# Baseflow at: 8075 grid cells.
# Baseflow at: 7918 grid cells.
# Baseflow at: 7918 grid cells.
# Baseflow at: 7918 grid cells.
# Baseflow at: 7918 grid cells.
# Baseflow at: 7918 grid cells.
# Baseflow at: 7918 grid cells.
# Time =  518016.67 [min],  Q_out =  111.87611 [m^3/s]
# Baseflow at: 7865 grid cells.
# Baseflow at: 7865 grid cells.
# Baseflow at: 7865 grid cells.
# Baseflow at: 7865 grid cells.
# Baseflow at: 7865 grid cells.
# Baseflow at: 7865 grid cells.
# Baseflow at: 8095 grid cells.
# Baseflow at: 8095 grid cells.
# Baseflow at: 8095 grid cells.
# Baseflow at: 8095 grid cells.
# Time =  518580.00 [min],  Q_out =  104.45402 [m^3/s]
# Baseflow at: 8095 grid cells.
# Baseflow at: 8095 grid cells.
# Baseflow at: 8365 grid cells.
# Baseflow at: 8365 grid cells.
# Baseflow at: 8365 grid cells.
# Baseflow at: 8365 grid cells.
# Baseflow at: 8365 grid cells.
# Baseflow at: 8365 grid cells.
# Baseflow at: 8349 grid cells.
# Time =  519150.00 [min],  Q_out =   96.86091 [m^3/s]
# Baseflow at: 8347 grid cells.
# Baseflow at: 8347 grid cells.
# Baseflow at: 8347 grid cells.
# Baseflow at: 8347 grid cells.
# Baseflow at: 8347 grid cells.
# Baseflow at: 8147 grid cells.
# Baseflow at: 8147 grid cells.
# Baseflow at: 8147 grid cells.
# Baseflow at: 8147 grid cells.
# Baseflow at: 8147 grid cells.
# Time =  519720.00 [min],  Q_out =   90.58169 [m^3/s]
# Baseflow at: 8147 grid cells.
# Baseflow at: 7814 grid cells.
# Baseflow at: 7814 grid cells.
# Baseflow at: 7814 grid cells.
# Baseflow at: 7814 grid cells.
# Baseflow at: 7814 grid cells.
# Baseflow at: 7814 grid cells.
# Baseflow at: 7875 grid cells.
# Baseflow at: 7875 grid cells.
# Time =  520305.00 [min],  Q_out =   85.69764 [m^3/s]
# Baseflow at: 7875 grid cells.
# Baseflow at: 7875 grid cells.
# Baseflow at: 7875 grid cells.
# Baseflow at: 7875 grid cells.
# Baseflow at: 7904 grid cells.
# Baseflow at: 7904 grid cells.
# Baseflow at: 7904 grid cells.
# Baseflow at: 7904 grid cells.
# Baseflow at: 7904 grid cells.
# Baseflow at: 7904 grid cells.
# Time =  520860.00 [min],  Q_out =   82.08849 [m^3/s]
# Baseflow at: 7832 grid cells.
# Baseflow at: 7832 grid cells.
# Baseflow at: 7832 grid cells.
# Baseflow at: 7832 grid cells.
# Baseflow at: 7832 grid cells.
# Baseflow at: 7832 grid cells.
# Baseflow at: 7881 grid cells.
# Baseflow at: 7881 grid cells.
# Baseflow at: 7881 grid cells.
# Time =  521430.00 [min],  Q_out =   79.19230 [m^3/s]
# Baseflow at: 7881 grid cells.
# Baseflow at: 7881 grid cells.
# Baseflow at: 7881 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Baseflow at: 7805 grid cells.
# Time =  521955.00 [min],  Q_out =   77.33909 [m^3/s]
# Baseflow at: 7783 grid cells.
# Baseflow at: 7783 grid cells.
# Baseflow at: 7783 grid cells.
# Baseflow at: 7783 grid cells.
# Baseflow at: 7783 grid cells.
# Baseflow at: 7783 grid cells.
# Baseflow at: 7835 grid cells.
# Baseflow at: 7835 grid cells.
# Baseflow at: 7835 grid cells.
# Time =  522525.00 [min],  Q_out =   75.45701 [m^3/s]
# Baseflow at: 7835 grid cells.
# Baseflow at: 7835 grid cells.
# Baseflow at: 7835 grid cells.
# Baseflow at: 8114 grid cells.
# Baseflow at: 8114 grid cells.
# Baseflow at: 8114 grid cells.
# Baseflow at: 8114 grid cells.
# Baseflow at: 8114 grid cells.
# Baseflow at: 8114 grid cells.
# Baseflow at: 8248 grid cells.
# Time =  523080.00 [min],  Q_out =   74.32416 [m^3/s]
# Baseflow at: 8248 grid cells.
# Baseflow at: 8248 grid cells.
# Baseflow at: 8248 grid cells.
# Baseflow at: 8248 grid cells.
# Baseflow at: 8248 grid cells.
# Baseflow at: 8669 grid cells.
# Baseflow at: 8668 grid cells.
# Baseflow at: 8668 grid cells.
# Baseflow at: 8668 grid cells.
# Time =  523650.00 [min],  Q_out =   74.41925 [m^3/s]
# Baseflow at: 8668 grid cells.
# Baseflow at: 8668 grid cells.
# Baseflow at: 9340 grid cells.
# Baseflow at: 9340 grid cells.
# Baseflow at: 9340 grid cells.
# Baseflow at: 9340 grid cells.
# Baseflow at: 9340 grid cells.
# Baseflow at: 9340 grid cells.
# Baseflow at: 9407 grid cells.
# Baseflow at: 9407 grid cells.
# Time =  524220.00 [min],  Q_out =   73.84009 [m^3/s]
# Baseflow at: 9407 grid cells.
# Baseflow at: 9407 grid cells.
# Baseflow at: 9407 grid cells.
# Baseflow at: 9407 grid cells.
# Baseflow at: 8917 grid cells.
# Baseflow at: 8917 grid cells.
# Baseflow at: 8917 grid cells.
# Baseflow at: 8917 grid cells.
# Baseflow at: 8917 grid cells.
# Time =  524790.00 [min],  Q_out =   74.10531 [m^3/s]
# Baseflow at: 8917 grid cells.
# Baseflow at: 9053 grid cells.
# Baseflow at: 9051 grid cells.
# Baseflow at: 9051 grid cells.
# Baseflow at: 9051 grid cells.
# Baseflow at: 9051 grid cells.
# Baseflow at: 9051 grid cells.
# Baseflow at: 8625 grid cells.
# Baseflow at: 8625 grid cells.
# Baseflow at: 8625 grid cells.
# Time =  525360.00 [min],  Q_out =   79.95699 [m^3/s]
# Baseflow at: 8625 grid cells.
# Baseflow at: 8625 grid cells.
# Baseflow at: 8625 grid cells.
# Stopping: Reached stop time = 525600.0.
#
# Meteorology component: Finished.
# Diversions component: Finished.
# Channels component: Finished.
# Snow component: Finished.
# Groundwater component: Finished.
# Evaporation component: Finished.
# Infiltration component: Finished.
# Ice component: Finished.
# =======================
# Simulation complete.
# =======================
#
# ------------------------------------------------------------
# TopoFlow Version 3.62 (2020-06-02)
# Tue Jul 27 14:21:36 2021
#
# Input directory:      /Users/peckhams/TF_Tests/Tana_120sec/
# Output directory:     /Users/peckhams/TF_Tests/Tana_120sec/
# Site prefix:          Tana_120sec
# Case prefix:          Test1
#
# Simulated time:      525600.0 [min]
# Program run time:    6.930843782424927 [min]
#
# Number of timesteps: 315360
# Number of columns:   131
# Number of rows:      115
#
# T_stop:            525600.0 [min]
#
# Main outlet ID:    (95, 119) (row, col)
# Basin_area:        94284.4 [km^2]
#
# Min Manning's n:   0.030000001192092896
# Max Manning's n:   1.0
#
# Q_final:           84.1583519867297 [m^3/s]
# Q_peak:            874.4555334770703 [m^3/s]
# Q_peak_time:       15915.0 [min]
# u_peak:            1.703205708887039 [m/s]
# u_peak_time:       15900.0 [min]
# d_peak:            3.8312175025982653 [m]
# d_peak_time:       15900.0 [min]
#
# Max(precip rate):  7.039565116429003 [mm/hr]
#
# Total accumulated volumes over entire DEM: (fluxes)
# vol_P    (precip):        23908.669520443855 x 10^6 [m^3]   (incl. leq snowfall)
# vol_Q    (discharge):     5288.35820444108 x 10^6 [m^3]   (main basin outlet)
# vol_SM   (snowmelt):      0.0 [m^3]
# vol_MR   (icemelt):       0.0 [m^3]
# vol_ET   (evaporation):   0.0 [m^3]
# vol_IN   (infiltration):  0.0 [m^3]
# vol_Rg   (recharge):      0.0 [m^3]   (bottom loss)
# vol_GW   (baseflow):      78706.33519686031 x 10^6 [m^3]
# vol_R    (runoff):        102614.65743852446 x 10^6 [m^3]  R = (P+SM+MR) - (ET+IN)
#
# Total accumulated volumes over entire DEM: (storage)
# vol_soil  (infiltration):  0.0 [m^3]  (change in storage)
# vol_chan0 (channels):      72.84777914048261 x 10^6 [m^3]  (initial)
# vol_chan  (channels):      155.8016079563824 x 10^6 [m^3]
# vol_land  (surface):       838.4859367325976 x 10^6 [m^3]
# vol_edge  (boundary):      101698.01688552347 x 10^6 [m^3]
# vol_swe   (snowpack):      0.0 [m^3]
#
# Mass balance check:
# volume in         = 102615.00471730417 x 10^6 [m^3]
# volume out        = 101698.01688552347 x 10^6 [m^3]
# change in storage = 921.4397655484975 x 10^6 [m^3]
# volume gain error = 4.451933767791748 x 10^6 [m^3]
# vol_error/ vol_in = 4.338482252236363e-05
#
# Final grid mins and maxes:
# Min(Q), Max(Q):   0.0000, 150.5164 [m^3/s]
# Min(u), Max(u):   0.0000, 2.1239 [m/s]
# Min(d), Max(d):   0.0000, 3.7413 [m]
#
# Finished.  (Test1)

# %% [markdown]
# ## Show a Grid from a Grid Stack in an RTS File  <a id="show_grid"></a>

# %%
long_name = 'River Discharge'
rts_filename = output_dir + cfg_prefix + '_2D-Q.rts'
rts = rts_files.rts_file()
OK  = rts.open_file( rts_filename )
if not(OK):
    print('Sorry, Could not open RTS file:')
    print( rts_filename )

n_grids = int( rts.number_of_grids() )
# time_index = 2
# time_index = int(n_grids / 2)
time_index = int(n_grids - 1)
byte_swap  = rts.byte_swap_needed()
grid   = rts.read_grid( time_index )   # alias to get_grid()
extent = rts.get_bounds()
rts.close_file()

print('Byte swap needed =', byte_swap )
print('Number of grids in RTS file  =', n_grids)
print('Reading one grid from RTS file... ')
print('  time_index =', time_index )
print('extent =', extent)
print('min(grid), max(grid) =', grid.min(), grid.max())
print('Finished.')
print()

tfvis.show_grid_as_image( grid, long_name, extent=extent,
                          BLACK_ZERO=True,
                          cmap='rainbow', stretch='power', p=0.3,
                          # a=1, b=2, p=0.5,
                          xsize=7, ysize=7, dpi=None)
# Out:
# Byte swap needed = False
# Number of grids in RTS file  = 4380
# Reading one grid from RTS file...
#   time_index = 4379
# extent = [36.4, 40.766666666667, -3.143333333333, 0.69]
# min(grid), max(grid) = 0.0 149.63693
# Finished.

# %% [markdown]
# ## Plot a Time Series for Outlet Values  <a id="plot_data"></a>

# %%
os.chdir(output_dir)
var_index = 3
nc_file = cfg_prefix + '_0D-Q.nc'
# nc_file = cfg_prefix + '_0D-d-flood.nc'

tfvis.plot_time_series(nc_file, output_dir=output_dir, var_index=var_index,
                       marker=',', REPORT=True, xsize=8, ysize=5)

# Save the image to a file instead
# im_file = cfg_prefix + '_0D-Q.png'
# # im_file = cfg_prefix + '_0D-d-flood.png'
# tfvis.plot_time_series(nc_file, output_dir=output_dir, var_index=var_index,
#                           marker=',', REPORT=True, xsize=10, ysize=4,
#                           im_file=im_file)
# Out:
# var_names in netCDF file =
# ['time', 'datetime', 'Q_95_119', 'Q_94_118']
# var longitudes =
# [40.38333333333333, 40.35]
# var latitudes =
# [-2.493333333333, -2.459999999999667]

# %%
from topoflow.utils import ncts_files
ncts = ncts_files.ncts_file()

# output_dir = '/Users/peckhams/TF_Tests/Tana_120sec/'
nc_file = output_dir + 'Test1' + '_0D-Q.nc'
# nc_file = cfg_prefix + '_0D-Q.nc'
ncts.open_file( nc_file )
var_name_list = ncts.get_var_names()
var_index = 2
var_name = var_name_list[ var_index ]
ts_values = ncts.get_values( var_name )
ts_times  = ncts.get_times()
ts_datetimes = ncts.get_datetimes()

values    = ts_values[:]
times     = ts_times[:]
datetimes = ts_datetimes[:]
print('n_values    =', values.size)
print('n_times     =', times.size)
print('Qmin, Qmax  =', values.min(), values.max())
print('tmin, tmax  =', times.min(), times.max())
print('times.dtype =', times.dtype)
print()
print('times[-10:-1] =')
print(times[-10:-1])
# print(times[-94])
print('datetimes[0:10] =')
print(datetimes[0:10])
# Out:
# n_values    = 35040
# n_times     = 35040
# Qmin, Qmax  = 0.0 874.4555
# tmin, tmax  = 0.0 525585.0
# times.dtype = float64
#
# times[-10:-1] =
# [525450. 525465. 525480. 525495. 525510. 525525. 525540. 525555. 525570.]
# datetimes[0:10] =
# ['2015-10-01 00:00:00' '2015-10-01 00:15:00' '2015-10-01 00:30:00'
#  '2015-10-01 00:45:00' '2015-10-01 01:00:00' '2015-10-01 01:15:00'
#  '2015-10-01 01:30:00' '2015-10-01 01:45:00' '2015-10-01 02:00:00'
#  '2015-10-01 02:15:00']

# %% [markdown]
# ## Test2:  CHIRPS Rainfall, with Richards 1D Infiltration <a id="Test2"></a>

# %% [markdown]
# In this test, we use everything exactly as in Test1, except we Enable the Richard 1D Infiltration component. So now only 3 process components are enabled, namely:  <b>Meteorology</b>, <b>Channels - Kinematic Wave</b> and <b>Infiltration - Richards 1D</b>.  All other processes (evaporation, snowmelt, icemelt, diversions) have <b>comp_status</b> set to Disabled in their CFG files.  The case prefix for this scenario is <b>Test2</b>.
#
# <b>Note:</b>  There is a problem when we set slope_file to
# site_prefix_new-slope.rtg, instead of site_prefix_slope.rtg in the channel process CFG file.

# %%
cfg_prefix = 'Test2'
cfg_dir = home_dir + '/TF_Tests/Tana_120sec/Test2/'
    
main.run_model(cfg_prefix=cfg_prefix, cfg_directory=cfg_dir)
# Out:
# EMELI: Reading info from provider_file:
#     /Users/peckhams/TF_Tests/Tana_120sec/Test2/Test2_providers.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-36dd6b5a0f99> in <module>
#       2 cfg_dir = home_dir + '/TF_Tests/Tana_120sec/Test2/'
#       3
# ----> 4 main.run_model(cfg_prefix=cfg_prefix, cfg_directory=cfg_dir)
#
# ~/Dropbox/TopoFlow_3.6/topoflow/main.py in run_model(driver_comp_name, cfg_prefix, cfg_directory, SILENT, time_interp_method)
#      38                  cfg_directory=cfg_directory,
#      39                  SILENT=SILENT,
# ---> 40                  time_interp_method=time_interp_method )
#      41
#      42 #   run_model()
#
# ~/Dropbox/TopoFlow_3.6/topoflow/framework/emeli.py in run_model(self, driver_comp_name, cfg_directory, cfg_prefix, SILENT, time_interp_method)
#    1262         # self.provider_file = (cfg_prefix + '_providers.txt')
#    1263         self.provider_file = provider_file
# -> 1264         self.read_provider_file()
#    1265
#    1266         #------------------------------------
#
# ~/Dropbox/TopoFlow_3.6/topoflow/framework/emeli.py in read_provider_file(self)
#     455         self.comp_set_list = []
#     456
# --> 457         file_unit = open( self.provider_file, 'r' )
#     458
#     459         #--------------------------------
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/peckhams/TF_Tests/Tana_120sec/Test2/Test2_providers.txt'
